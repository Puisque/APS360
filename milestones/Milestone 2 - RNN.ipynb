# %% [markdown]
# # Data loading

# %%
######## >>>>>>>>>>> For the google colab to be able to access the meta files you must add the APS360 team shared folder to your drive by right clicking on it <<<<<<<<<<< ##############
#mount googledrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
# Prints how many nulls there are in max and min temp
def test_null_csv_daily(station, start_year, end_year, out_name =  None):
    """
      Args:
          station (string): eg. "ON_6158355"
          start_year (int): Starting year
          end_year (int)  : Ending year
          start_date (int): start_date = 0 is day 1 of starting year (Where we want the sampling to start)
          out_name (optional string) : change the name of the output file
    """
    if out_name == None:
      out_name = station + '_' + str(start_year) + '-' + str(end_year)
    master_path = '/content/gdrive/My Drive/APS360 Team/milestone 1/'
    src_path = master_path + 'datasets/'
    newdf = pd.read_csv(src_path + out_name + ".csv")
    print("Max temp nulls: " + str(newdf['Max Temp (°C)'].isnull().sum()))
    print("Min temp nulls: " + str(newdf['Min Temp (°C)'].isnull().sum()))

# %%
import pandas as pd
# Interpolates null values in min and max temp cols
def inter_nulls_csv_daily(station, start_year, end_year, out_name =  None):
    """
      Args:
          station (string): eg. "ON_6158355"
          start_year (int): Starting year
          end_year (int)  : Ending year
          start_date (int): start_date = 0 is day 1 of starting year (Where we want the sampling to start)
          out_name (optional string) : change the name of the output file
    """
    if out_name == None:
      out_name = station + '_' + str(start_year) + '-' + str(end_year)
    master_path = '/content/gdrive/My Drive/APS360 Team/milestone 1/'
    src_path = master_path + 'datasets/'
    newdf = pd.read_csv(src_path + out_name + ".csv")
    newdf['Max Temp (°C)'] = newdf['Max Temp (°C)'].interpolate()
    newdf['Min Temp (°C)']= newdf['Min Temp (°C)'].interpolate()
    newdf.to_csv( src_path +  out_name + ".csv")

# %%
#Raw csv downloaded must be place in /raw folder
#Merged csv will be stored at /datasets folder
# Also interpolates the null max and min temp
def make_csv_daily(station, start_year, end_year, out_name =  None):
  """
    Args:
        station (string): eg. "ON_6158355"
        start_year (int): Starting year
        end_year (int)  : Ending year
        start_date (int): start_date = 0 is day 1 of starting year (Where we want the sampling to start)
        out_name (optional string) : change the name of the output file
    """
  if out_name == None:
    out_name = station + '_' + str(start_year) + '-' + str(end_year)
  master_path = '/content/gdrive/My Drive/APS360 Team/milestone 1/'
  src_path = master_path + 'raw/'
  dest_path = master_path + 'datasets/'
  fout = open(dest_path + out_name + ".csv","w+")
  in_base = "en_climate_daily_" + station + '_' #eg: 'en_climate_daily_ON_6158355_'
  in_end = '_P1D.csv'
  # first file:
  for line in open(src_path + in_base + str(start_year) + in_end):
      fout.write(line)
  # now the rest:    
  for num in range(start_year + 1, end_year + 1):
      f = open(src_path + in_base + str(num) + in_end)
      f.__next__() # skip the header
      for line in f:
          fout.write(line)
      f.close() # not really needed
  fout.close()
  inter_nulls_csv_daily(station, start_year, end_year, out_name)

# %%
####### run once #######
make_csv_daily("ON_6158355", 2007, 2016) # run once
make_csv_daily("ON_6158355", 2017, 2018) # run once
test_null_csv_daily("ON_6158355", 2007, 2016)
test_null_csv_daily("ON_6158355", 2017, 2018)
# Out:
# Max temp nulls: 0
# Min temp nulls: 0
# Max temp nulls: 0
# Min temp nulls: 0

# %%
import pandas as pd
import numpy as np
from torch.utils.data import Dataset, DataLoader
class WeatherDataset(Dataset):
    """Weather dataset."""

    def __init__(self, station, start_year, end_year, start_date = 0, end_date = None, num_days = 7, make_csv = False, out_name = None):
        """
        Args:
            station (string): eg. "ON_6158355"
            start_year (int): Starting year
            end_year (int)  : Ending year
            start_date (int): start_date = 0 is day 1 of starting year (Where we want the sampling to start)
            end_date (optional int) : end_date = 7 is day 8 of starting year(min = 7 because of LABEL!). If provided changes the end date from last day of last year.
            num_days (optional int) : num_days is the interval of days before the label.
            make_csv (optional bool): If true it will call make_csv_daily function to create the csv from /raw datasets into /datasets
            out_name (optional string) : change the name of the output file which it reads from
        """
        self.num_days = num_days
        if(out_name == None):
          self.out_name = station + '_' + str(start_year) + '-' + str(end_year)
        else:
          self.out_name = out_name
        master_path = '/content/gdrive/My Drive/APS360 Team/milestone 1/'
        dest_path = master_path + 'datasets/'
        if (make_csv):
          make_csv_daily(station, start_year, end_year, out_name =  out_name)

        self.cur_csv = pd.read_csv(dest_path + self.out_name +'.csv')

        self.start_date = start_date
        if( end_date == None):
          self.end_date = len(self.cur_csv) - start_date
        else:
          self.end_date = end_date

    def __len__(self):
        return self.end_date - self.start_date + 1 - self.num_days - 1

    def __getitem__(self, idx):
        data = self.cur_csv.loc[ idx + self.start_date : idx + self.start_date + self.num_days - 1 , ['Max Temp (°C)', 'Min Temp (°C)'] ]
        data = np.asarray(data)
        data = data.astype('float')

        label = self.cur_csv.loc[ idx + self.start_date + self.num_days, ['Max Temp (°C)', 'Min Temp (°C)'] ]
        label = np.asarray(label)
        label = label.astype('float')

        data = data.flatten()

        #print('Data: {}'.format(data))
        #print('Data shape: {}'.format(data.shape))
        #print('Labels shape: {}'.format(label.shape))
        #print('Labels: {}'.format(label[:2]))
        sample = [data, label]

        return sample

# %%
start_year_train = 2007
end_year_train = 2016 #changed from 2019 because in our proposal we said 07-16 is train
start_date_train = 0
end_date_train = None
num_days_train = 7
station = "ON_6158355"
trainingSet = WeatherDataset(station, start_year_train, end_year_train, start_date_train, end_date_train, num_days=num_days_train, make_csv = False)

# %%
trainingSet[2]
# Out:
# [array([ 8.1,  2.4, 10.1,  4.8, 11.9,  7.7, 10. ,  4.1,  4.8,  3.3,  5.4,
#          0.5,  2.5, -3.7]), array([-1.9, -5.7])]

# %%
start_year_val = 2017
end_year_val = 2018
start_date_val = 0
end_date_val = None
num_days_val = 7
# station stays the same
validationSet = WeatherDataset(station, start_year_val, end_year_val, start_date_val, end_date_val, num_days_val, make_csv = False)

# %%
import torch
train_loader = torch.utils.data.DataLoader(trainingSet, batch_size=2, 
                                            num_workers=1, shuffle=True)
for i, data in enumerate(train_loader, 0):
  input, label = data
  print("input:")
  print(input)
  print("label:")
  print(label)
# Out:
# Streaming output truncated to the last 5000 lines.
#        dtype=torch.float64)
# label:
# tensor([[ -3.7500, -13.1000],
#         [ 27.0000,  17.9000]], dtype=torch.float64)
# input:
# tensor([[  0.0000,  -9.3000,  -3.0000, -11.0000,   8.1000,  -3.3000,  12.9000,
#            4.8000,   7.6000,  -1.0000,   1.0000,  -3.8000,   0.8000,  -2.7000],
#         [ 12.7000,   2.1000,   8.8000,   2.8000,   9.0000,   1.1000,   7.5000,
#           -1.0000,   6.3000,  -0.6000,  11.4000,   4.3000,  12.8000,   7.6000]],
#        dtype=torch.float64)
# label:
# tensor([[ 2.7000, -0.4000],
#         [13.5000,  6.4000]], dtype=torch.float64)
# input:
# tensor([[27.9000, 19.3000, 26.9000, 20.3000, 28.5000, 18.2000, 31.7000, 20.1000,
#          32.7000, 22.8000, 33.7000, 23.4000, 33.9000, 21.7000],
#         [32.3000, 20.6000, 33.5000, 18.4000, 23.7000, 17.4000, 26.5000, 16.0000,
#          19.6000, 14.8000, 27.9000, 15.6000, 25.9000, 18.4000]],
#        dtype=torch.float64)
# label:
# tensor([[27.1000, 17.9000],
#         [26.0000, 15.3000]], dtype=torch.float64)
# input:
# tensor([[ -2.8000, -10.0000,   0.7000,  -3.7000,   3.5000,  -0.7000,   1.8000,
#            0.0000,   1.3000,  -0.6000,   2.2000,  -2.3000,   1.9000,  -6.5000],
#         [ 13.8000,   4.4000,   9.2000,   3.0000,  11.4000,   6.8000,  11.5000,
#            7.0000,  13.9000,   5.1000,  16.6000,   6.4000,  12.9000,   5.9000]],
#        dtype=torch.float64)
# label:
# tensor([[ -6.5000, -14.1000],
#         [ 16.5000,   9.2000]], dtype=torch.float64)
# input:
# tensor([[ 6.5000,  1.6000, 15.2000,  4.6000, 11.6000,  5.3000,  9.2000,  3.3000,
#          14.1000,  8.9000, 16.1000,  5.4000, 12.4333,  3.5000],
#         [ 8.3000,  3.0000, 13.1000,  8.0000, 13.9000, 10.1000, 12.5000,  2.0000,
#           4.1000,  0.6000,  7.9000,  2.9000,  4.8000,  2.6000]],
#        dtype=torch.float64)
# label:
# tensor([[8.7667, 3.2000],
#         [3.1000, 1.1000]], dtype=torch.float64)
# input:
# tensor([[ -5.2000, -11.7000,  -6.5000, -13.2000,  -8.5000, -13.9000,  -8.6000,
#          -14.2000,  -7.2000, -12.1000,  -5.7000, -12.0000,  -8.8000, -13.6000],
#         [ 15.2000,   3.7000,  18.3000,   7.3000,  24.3000,  10.7000,  21.2000,
#           12.4000,  17.8000,   9.0000,  23.8000,  11.4000,  14.4000,   9.1000]],
#        dtype=torch.float64)
# label:
# tensor([[ -5.2000, -14.1000],
#         [ 17.2000,   7.8000]], dtype=torch.float64)
# input:
# tensor([[  1.4000,  -9.2000,   6.9000,   1.2000,  10.6000,   3.9000,   4.9000,
#          -14.0000,  -6.1000, -16.5000,  10.5000,  -6.1000,   6.1000,  -7.3000],
#         [ 27.3000,  16.1000,  34.2000,  20.1000,  27.7000,  13.9000,  19.6000,
#           13.0000,  20.2000,  15.8000,  19.9000,  14.3000,  19.3000,  12.6000]],
#        dtype=torch.float64)
# label:
# tensor([[ -7.1000, -12.6000],
#         [ 19.7000,  13.2000]], dtype=torch.float64)
# input:
# tensor([[15.9000,  6.6000, 17.6000,  9.3000, 13.1000,  8.6000, 11.4000,  8.5000,
#          16.5000,  8.3000, 18.2000,  7.2000, 12.7000,  9.1000],
#         [ 4.4000,  1.0000, 16.9000,  3.3000, 16.6000,  8.2000,  8.8000,  3.1000,
#           7.4000,  0.6000, 12.1000,  2.7000,  6.8000,  2.3000]],
#        dtype=torch.float64)
# label:
# tensor([[12.6000, 10.1000],
#         [ 9.0000,  4.6000]], dtype=torch.float64)
# input:
# tensor([[ 30.5000,  21.3000,  31.6000,  22.0000,  31.7000,  20.2000,  24.4000,
#           14.9000,  24.3000,  13.0000,  26.2000,  18.9000,  28.1000,  20.3000],
#         [ -6.8000, -13.4000,  -4.7000, -14.5000,   5.0000,  -4.8000,  10.3000,
#           -2.9000,  -2.9000,  -7.5000,  -0.3000,  -8.8000,  -5.3000, -10.1000]],
#        dtype=torch.float64)
# label:
# tensor([[29.8000, 21.1000],
#         [-1.5000, -7.3000]], dtype=torch.float64)
# input:
# tensor([[31.8000, 20.4000, 32.2000, 21.9000, 30.8000, 21.2000, 30.9000, 18.2000,
#          27.7000, 17.8000, 28.1000, 17.0000, 27.3000, 15.8000],
#         [10.1000,  5.7000, 14.4000,  5.2000, 10.7000,  7.0000, 12.2000,  6.6000,
#          14.5000,  6.0000, 15.2000,  7.0000, 16.9000,  9.3000]],
#        dtype=torch.float64)
# label:
# tensor([[25.9000, 16.6000],
#         [21.0000,  9.7000]], dtype=torch.float64)
# input:
# tensor([[21.9000, 15.3000, 27.0000, 15.3000, 31.2000, 18.7000, 27.0000, 15.7000,
#          27.6000, 14.5000, 31.6000, 18.7000, 35.5000, 21.5000],
#         [17.3000,  5.2000, 18.1000,  6.0000, 18.5000,  4.6000, 13.0000,  3.6000,
#          12.6000,  3.8000, 16.8000,  7.6000, 13.1000,  9.9000]],
#        dtype=torch.float64)
# label:
# tensor([[33.7000, 22.0000],
#         [16.6000,  7.1000]], dtype=torch.float64)
# input:
# tensor([[25.3000, 16.4000, 29.4000, 18.2000, 32.9000, 21.2000, 33.6000, 19.4000,
#          31.1000, 19.5000, 30.4000, 17.2000, 28.2000, 19.2000],
#         [21.2000, 13.5000, 22.7000, 12.4000, 24.4000, 12.6000, 24.8000, 14.6000,
#          24.2000, 15.2000, 19.3000, 16.0000, 16.6000, 14.9000]],
#        dtype=torch.float64)
# label:
# tensor([[34.5000, 20.3000],
#         [18.4000, 15.2000]], dtype=torch.float64)
# input:
# tensor([[ -7.7000, -12.7000, -10.3000, -18.3000,  -4.3000, -18.5000,   0.7000,
#           -4.3000,  -0.5000,  -1.6000,   0.5000,  -2.4000,  -0.2000,  -3.8000],
#         [  8.9000,   7.0000,   8.0000,   4.6000,   5.5000,   3.0000,   6.8000,
#            2.1000,   2.9000,   1.0000,   2.5000,  -0.8000,   3.4000,  -0.7000]],
#        dtype=torch.float64)
# label:
# tensor([[-3.2000, -7.2000],
#         [ 6.3000,  0.8000]], dtype=torch.float64)
# input:
# tensor([[ -4.7000, -10.5000,  -2.9000,  -8.6000,   2.9000,  -4.9000,   2.8000,
#           -6.2000,   1.4000,  -9.2000,   6.9000,   1.2000,  10.6000,   3.9000],
#         [ 17.8000,   9.9000,  19.5000,  10.7000,  18.5000,  14.7000,  21.9000,
#           12.6000,  22.5000,  15.5000,  24.2000,  16.4000,  19.3000,  14.9000]],
#        dtype=torch.float64)
# label:
# tensor([[  4.9000, -14.0000],
#         [ 21.3000,  12.7000]], dtype=torch.float64)
# input:
# tensor([[ 23.2000,  18.4000,  23.1000,  18.1000,  22.0000,  15.8000,  18.9000,
#           14.7000,  17.3000,   9.2000,  12.2000,   6.5000,  10.5000,   5.0000],
#         [  3.7000,   0.2000,   3.5000,  -3.5000,  -2.0000, -10.9000,  -7.1000,
#          -12.2000,  -4.4000, -11.2000,   0.8000,  -6.6000,  -4.2000,  -7.8000]],
#        dtype=torch.float64)
# label:
# tensor([[14.5000, 10.1000],
#         [-5.0000, -7.9000]], dtype=torch.float64)
# input:
# tensor([[11.1000,  2.5000, 10.4000,  2.7000, 11.5000,  4.0000,  9.4000,  5.0000,
#          12.2000,  3.5000, 12.1000,  2.9000, 11.5000,  5.2000],
#         [12.2000,  1.8000, 10.6000,  4.8000, 10.4000,  4.5000, 11.9000,  2.9000,
#          12.6000,  6.0000,  8.1000,  5.9000,  6.7000,  5.1000]],
#        dtype=torch.float64)
# label:
# tensor([[11.3000,  4.6000],
#         [15.0000,  6.2000]], dtype=torch.float64)
# input:
# tensor([[22.6000, 10.1000, 30.6000, 13.1000, 19.7000, 13.8000, 19.4000, 11.7000,
#          21.0000, 10.9000, 24.3000, 11.9000, 25.6000, 15.2000],
#         [27.8000, 16.9000, 21.9000, 15.3000, 27.0000, 15.3000, 31.2000, 18.7000,
#          27.0000, 15.7000, 27.6000, 14.5000, 31.6000, 18.7000]],
#        dtype=torch.float64)
# label:
# tensor([[28.8000, 15.2000],
#         [35.5000, 21.5000]], dtype=torch.float64)
# input:
# tensor([[25.8000, 18.9000, 29.3000, 19.9000, 25.3000, 16.5000, 25.6000, 14.5000,
#          29.9000, 18.7000, 29.3000, 21.2000, 29.4000, 22.7000],
#         [ 5.4000, -1.1000, 12.0000,  2.7000, 11.3000,  6.2000, 13.1000,  2.7000,
#          10.7000,  1.9000, 12.3000,  2.7000, 17.7000,  6.3000]],
#        dtype=torch.float64)
# label:
# tensor([[29.4000, 20.8000],
#         [19.3000,  9.1000]], dtype=torch.float64)
# input:
# tensor([[20.9000, 11.9000, 18.4000,  8.6000,  9.4000,  6.1000,  6.5000,  5.1000,
#           7.7000,  4.6000, 13.9000,  7.3000,  8.9000,  7.0000],
#         [23.8000, 17.0000, 24.5000, 16.5000, 24.1000, 18.1000, 22.1000, 17.5000,
#          24.5500, 18.5000, 27.0000, 20.4000, 25.0000, 20.4000]],
#        dtype=torch.float64)
# label:
# tensor([[ 8.0000,  4.6000],
#         [28.9000, 19.8000]], dtype=torch.float64)
# input:
# tensor([[27.4000, 16.8000, 21.5000, 13.7000, 23.3000, 13.6000, 23.2000, 15.3000,
#          22.7000, 19.0000, 22.7000, 15.8000, 21.8000, 14.6000],
#         [20.8000, 10.9000, 18.6000, 12.5000, 19.5000, 12.8000, 21.4000, 13.7000,
#          19.5000, 14.6000, 22.6000, 12.3000, 25.7000, 14.5000]],
#        dtype=torch.float64)
# label:
# tensor([[23.7000, 14.5000],
#         [21.3000, 10.5000]], dtype=torch.float64)
# input:
# tensor([[10.7000,  3.7000,  7.5000,  1.2000,  4.9000,  1.5000,  6.6000,  0.9000,
#           9.6000,  2.8000, 10.3000,  2.2000, 13.0000,  1.6000],
#         [12.3000,  3.9000, 25.0000,  7.3000, 23.7000, 10.8000, 17.8000,  8.9000,
#          19.4000, 11.0000, 22.6000, 12.4000, 26.3000, 14.2000]],
#        dtype=torch.float64)
# label:
# tensor([[16.5000, 11.7000],
#         [22.3000, 14.5000]], dtype=torch.float64)
# input:
# tensor([[ 0.4000, -2.9000,  2.0000, -0.6000,  3.8000,  0.1000,  9.1000,  0.8000,
#           0.8000, -4.4000, -2.2000, -6.8000,  0.5000, -3.9000],
#         [ 4.7000,  2.3000,  2.9000, -0.6000,  3.0000, -0.4000,  2.3000, -1.0000,
#           2.3000, -2.0000, -1.0000, -5.4000,  0.9000, -5.9000]],
#        dtype=torch.float64)
# label:
# tensor([[ 3.0000,  0.2000],
#         [ 2.6000, -1.2000]], dtype=torch.float64)
# input:
# tensor([[21.3000, 10.7000, 22.4000, 12.3000, 24.4000, 14.5000, 28.9000, 15.6000,
#          30.5000, 17.2000, 34.2000, 21.3000, 33.0000, 23.1000],
#         [24.4000, 13.0000, 23.7000, 14.4000, 19.6000, 15.3000, 18.0000, 16.3000,
#          22.5000, 13.4000, 14.9000, 12.1000, 18.7000, 13.6000]],
#        dtype=torch.float64)
# label:
# tensor([[33.2000, 22.9000],
#         [16.0000,  9.2000]], dtype=torch.float64)
# input:
# tensor([[28.7000, 19.4000, 28.2000, 18.3000, 30.4000, 21.8000, 31.4000, 23.5000,
#          28.8000, 18.9000, 25.9000, 16.3000, 29.9000, 16.8000],
#         [29.1000, 18.6000, 26.3000, 17.1000, 20.9000, 17.3000, 24.2000, 15.6000,
#          26.6000, 16.4000, 19.3000, 12.1000, 19.7000, 12.0000]],
#        dtype=torch.float64)
# label:
# tensor([[29.9000, 21.5000],
#         [21.3000, 10.0000]], dtype=torch.float64)
# input:
# tensor([[  6.0000,   1.8000,   4.4000,   2.1000,   5.0000,   0.7000,   2.0000,
#          -10.2000,   0.7000, -10.3000,   1.5000,  -2.3000,   4.4000,   1.5000],
#         [  6.1000,   2.5000,   6.6000,   1.2000,   9.7000,   0.9000,   6.4000,
#           -3.4000,   3.1000,  -4.9000,   1.5000,  -5.4000,   7.7000,  -0.6000]],
#        dtype=torch.float64)
# label:
# tensor([[ 7.6000,  1.8000],
#         [ 6.5000, -5.2000]], dtype=torch.float64)
# input:
# tensor([[  4.4000,   2.3000,   7.9000,   3.7000,   7.3000,   3.2000,   8.3000,
#            3.5000,   8.1000,   4.8000,  13.2000,   6.4000,  12.5000,   8.0000],
#         [ -2.2000,  -5.7000,  -3.9000,  -7.0000,  -4.4000, -10.0000,  -0.9000,
#          -10.7000,   0.7000,  -3.9000,  -0.2000,  -3.1000,   5.7000,  -3.5000]],
#        dtype=torch.float64)
# label:
# tensor([[8.4000, 4.8000],
#         [9.9000, 5.3000]], dtype=torch.float64)
# input:
# tensor([[34.2000, 21.3000, 33.0000, 23.1000, 33.2000, 22.9000, 34.1000, 24.6000,
#          26.5000, 19.8000, 28.9000, 18.5000, 28.8000, 17.6000],
#         [18.3000,  8.4000, 14.3000,  5.0000, 15.1000,  4.1000, 15.8000,  7.2000,
#          17.6000,  8.7000, 21.2000, 10.8000, 21.1000, 13.8000]],
#        dtype=torch.float64)
# label:
# tensor([[26.2000, 20.8000],
#         [15.5000,  3.6000]], dtype=torch.float64)
# input:
# tensor([[24.7000, 19.1000, 26.3000, 16.0000, 22.6000, 13.8000, 27.6000, 14.7000,
#          33.0000, 19.7000, 26.4000, 19.0000, 27.1000, 18.7000],
#         [ 9.5000,  0.1000,  9.1000,  2.8000, 11.6000,  2.6000, 14.7000,  6.5000,
#           6.5000, -2.2000,  1.9000, -4.3000,  5.6000, -2.1000]],
#        dtype=torch.float64)
# label:
# tensor([[27.5000, 19.4000],
#         [ 6.9000, -1.8000]], dtype=torch.float64)
# input:
# tensor([[30.7000, 20.7000, 26.5000, 17.9000, 28.8000, 18.0000, 28.4000, 18.1000,
#          24.0000, 16.0000, 23.7000, 14.3000, 23.3000, 15.1000],
#         [29.3000, 23.0000, 26.9000, 21.6000, 29.9000, 20.1000, 30.2000, 21.3000,
#          32.8000, 21.5000, 29.3000, 22.5000, 25.1000, 17.1000]],
#        dtype=torch.float64)
# label:
# tensor([[23.8000, 14.3000],
#         [23.5000, 14.3000]], dtype=torch.float64)
# input:
# tensor([[ 6.0000,  1.9000,  3.9000,  0.3000,  1.0000, -2.4000, -0.2000, -6.5000,
#          -0.7000, -6.4000,  0.6000, -4.7000,  3.3000, -0.7000],
#         [20.4000,  9.0000, 15.2000,  8.2000, 14.2000,  6.3000, 23.7000, 11.2000,
#          24.7000, 10.3000, 15.2000,  9.4000, 22.1000,  9.0000]],
#        dtype=torch.float64)
# label:
# tensor([[-0.1000, -5.2000],
#         [23.0000, 12.1000]], dtype=torch.float64)
# input:
# tensor([[12.2000,  4.7000, 10.6000,  5.1000, 13.8000,  3.7000,  5.9000, -0.1000,
#           8.2000,  3.5000,  7.2000,  1.6000,  3.3000,  1.4000],
#         [24.3000, 13.4000, 23.9000, 14.7000, 23.2000, 15.9000, 19.3000, 14.3000,
#          18.1000, 13.3000, 23.5000, 13.7000, 17.0000, 14.9000]],
#        dtype=torch.float64)
# label:
# tensor([[ 5.6000,  0.3000],
#         [27.5000, 15.8000]], dtype=torch.float64)
# input:
# tensor([[  5.0000,  -4.8000,  10.3000,  -2.9000,  -2.9000,  -7.5000,  -0.3000,
#           -8.8000,  -5.3000, -10.1000,  -1.5000,  -7.3000,   2.6000,  -4.6000],
#         [ 28.4000,  13.4000,  28.0000,  19.5000,  26.6000,  18.6000,  30.0000,
#           18.4000,  25.1000,  17.1000,  22.7000,  15.4000,  19.3000,   7.4000]],
#        dtype=torch.float64)
# label:
# tensor([[ 8.2000,  1.8000],
#         [17.3000,  8.1000]], dtype=torch.float64)
# input:
# tensor([[ -3.2000,  -7.8000,  -4.8000, -10.9000,  -3.0000, -11.2000,  -0.8000,
#           -4.8000,   0.6000,  -7.0000,   2.6000,  -6.3000,   2.7000,  -4.1000],
#         [ -1.4000,  -8.8000,  -0.1000,  -9.6000,   1.6000,  -5.7000,   0.1000,
#           -6.8000,   1.6000,  -1.8000,  -1.7000,  -7.5000,  -4.9000, -10.4000]],
#        dtype=torch.float64)
# label:
# tensor([[  1.4000,  -7.0000],
#         [ -6.4000, -10.6000]], dtype=torch.float64)
# input:
# tensor([[  0.1000,  -6.8000,   1.6000,  -1.8000,  -1.7000,  -7.5000,  -4.9000,
#          -10.4000,  -6.4000, -10.6000,  -4.4000, -11.0000,  -1.4000,  -7.5000],
#         [ 27.7000,  13.2000,  20.2000,  16.3000,  20.9000,  16.3000,  24.7000,
#           15.5000,  27.2000,  16.6000,  29.1000,  17.0000,  30.6000,  19.6000]],
#        dtype=torch.float64)
# label:
# tensor([[  1.6000, -14.5000],
#         [ 29.7000,  20.2000]], dtype=torch.float64)
# input:
# tensor([[ 7.9000,  3.7000,  7.3000,  3.2000,  8.3000,  3.5000,  8.1000,  4.8000,
#          13.2000,  6.4000, 12.5000,  8.0000,  8.4000,  4.8000],
#         [10.5000,  4.2500, 10.4000,  6.5000, 10.8000,  6.1000, 10.8000,  5.5000,
#          21.9000,  8.0000, 15.1000,  9.1000, 20.0000,  9.5000]],
#        dtype=torch.float64)
# label:
# tensor([[ 6.7000,  2.7000],
#         [20.5000, 11.3000]], dtype=torch.float64)
# input:
# tensor([[17.0000,  8.8000, 13.9000,  9.0000, 17.1000,  8.7000, 14.8000,  7.8000,
#          14.0000,  8.3000, 16.9000,  7.1000, 11.9000,  8.2000],
#         [14.8000,  0.2000,  9.0000,  5.4000, 14.5000,  6.8000, 14.5000,  7.8000,
#          20.3000,  9.3000, 23.5000, 13.0000, 13.8000,  9.8000]],
#        dtype=torch.float64)
# label:
# tensor([[13.5000,  7.3000],
#         [17.6000,  8.8000]], dtype=torch.float64)
# input:
# tensor([[ -3.7000,  -8.4000,   0.0000,  -3.8500,   5.5000,   0.7000,   1.1000,
#           -7.7000,  -4.8000, -11.7000,  -2.7000, -10.5000,   0.5000,  -7.0000],
#         [ 12.8000,   7.8000,   9.9000,   7.9000,  14.5000,   7.9000,  18.5000,
#           11.5000,  18.9000,   9.6000,  24.5000,  13.7000,  26.3000,  14.8000]],
#        dtype=torch.float64)
# label:
# tensor([[ 1.3000, -3.6000],
#         [21.4000, 14.9000]], dtype=torch.float64)
# input:
# tensor([[  3.2000,  -3.6000,   1.9000,  -6.1000,   3.4000,  -0.1000,   7.0000,
#            1.9000,   6.6000,   2.5000,   8.1000,   3.7000,  13.0000,   6.7000],
#         [ 13.4000,   6.9000,   8.1000,  -5.6000,  -5.5000,  -9.1000,  -4.6000,
#           -9.3000,  -3.5000,  -9.4000,  -4.8000, -10.3000,  -2.8000, -10.4000]],
#        dtype=torch.float64)
# label:
# tensor([[14.7000,  5.2000],
#         [-2.3000, -6.7000]], dtype=torch.float64)
# input:
# tensor([[ 1.7000, -9.0000,  9.0000, -3.5000, 17.4000,  4.0000,  6.4000,  1.8000,
#           5.7000,  1.3000,  4.7000,  0.6000,  4.0000,  0.9000],
#         [10.4000,  2.1000, 17.5000,  3.9000, 14.0000,  6.2000, 14.2000,  5.4000,
#          18.4000,  5.1000, 20.3000,  2.7000,  2.8000, -4.4000]],
#        dtype=torch.float64)
# label:
# tensor([[ 8.4000, -4.4000],
#         [ 3.8000, -5.0000]], dtype=torch.float64)
# input:
# tensor([[ 4.0000, -0.6000,  7.6000, -0.4000,  0.7000, -5.0000,  6.0000, -4.1000,
#          11.8000,  5.9000,  8.9000,  4.7000, 15.4000,  6.6000],
#         [ 7.4000,  4.9000,  5.9000,  3.5000,  6.9500,  2.1000,  8.0000,  2.7000,
#          10.1000,  5.7000, 14.4000,  5.2000, 10.7000,  7.0000]],
#        dtype=torch.float64)
# label:
# tensor([[ 6.6000, -3.0000],
#         [12.2000,  6.6000]], dtype=torch.float64)
# input:
# tensor([[18.6000, 14.5000, 18.7000, 13.5000, 30.6000, 16.8000, 31.1000, 20.4000,
#          32.3000, 20.6000, 33.5000, 18.4000, 23.7000, 17.4000],
#         [31.1500, 25.0000, 29.5000, 22.5000, 28.8000, 20.4000, 25.8000, 18.5000,
#          28.5000, 19.2000, 26.6000, 19.7000, 27.7000, 20.2000]],
#        dtype=torch.float64)
# label:
# tensor([[26.5000, 16.0000],
#         [29.8000, 20.3000]], dtype=torch.float64)
# input:
# tensor([[14.8000,  7.8000, 14.0000,  8.3000, 16.9000,  7.1000, 11.9000,  8.2000,
#          13.5000,  7.3000,  9.7000,  2.3000,  7.0000,  1.5000],
#         [20.4000,  8.9000, 16.4000,  7.8000, 18.7000, 13.5000, 20.8000, 12.3000,
#          18.1000,  9.9000, 15.2000,  7.3000, 15.7000,  6.0000]],
#        dtype=torch.float64)
# label:
# tensor([[10.7000,  3.7000],
#         [20.2000, 11.3000]], dtype=torch.float64)
# input:
# tensor([[  4.9000,   1.7000,   6.6000,   2.5000,   7.2000,   3.5000,  11.1000,
#            6.6000,  14.2000,   9.6000,  11.0000,   1.3000,   5.4000,   0.3000],
#         [  1.2000,  -4.2000,  -2.0000, -11.2000,  -7.3000, -13.1000,  -4.5000,
#          -11.3000,  -0.7000, -11.8000,   1.1000,  -3.9000,  -0.8000, -13.7000]],
#        dtype=torch.float64)
# label:
# tensor([[  3.4000,  -2.7000],
#         [ -1.9000, -13.8000]], dtype=torch.float64)
# input:
# tensor([[12.9000,  4.4000,  6.1000, -2.3000,  2.7000, -4.0000, -0.7000, -5.7000,
#           0.2000, -6.8000,  7.1000, -1.2000,  8.3000, -0.1000],
#         [25.3000, 16.5000, 25.6000, 14.5000, 29.9000, 18.7000, 29.3000, 21.2000,
#          29.4000, 22.7000, 29.4000, 20.8000, 21.9000, 19.6000]],
#        dtype=torch.float64)
# label:
# tensor([[ 5.0000, -3.0000],
#         [24.4000, 19.5000]], dtype=torch.float64)
# input:
# tensor([[ -8.2000, -14.2000,  -8.3000, -16.0000,  -6.9000, -17.7000,  -0.7000,
#          -10.2000,  -8.5000, -15.5000, -10.9000, -18.4000,  -8.1000, -15.6000],
#         [ 11.1000,   0.1000,   0.1000,  -6.1000,  -3.2000,  -8.8000,  -5.1000,
#          -10.5000,  -3.9000, -12.9000,  -0.1000,  -6.8000,   3.1000,  -1.9000]],
#        dtype=torch.float64)
# label:
# tensor([[ -4.7000, -10.5000],
#         [  1.6000,  -6.2000]], dtype=torch.float64)
# input:
# tensor([[15.2000,  7.3000, 15.7000,  6.0000, 20.2000, 11.3000, 18.4000,  9.8000,
#          16.6000,  8.4000, 18.1000, 10.3000, 18.4000, 10.0000],
#         [28.3000, 15.6000, 30.0000, 16.7000, 32.6000, 20.5000, 31.1000, 22.2000,
#          31.2000, 22.1000, 29.6000, 22.8000, 25.9000, 16.8000]],
#        dtype=torch.float64)
# label:
# tensor([[16.6000, 10.6000],
#         [17.3000, 12.5000]], dtype=torch.float64)
# input:
# tensor([[21.8000, 12.8000, 21.9000, 13.5000, 24.1000, 12.3000, 25.1000, 13.7000,
#          26.7000, 16.2000, 26.4000, 16.7000, 27.4000, 16.9000],
#         [20.3000,  9.1000, 14.4000,  5.3000, 13.9000,  3.4000, 16.8000,  6.1000,
#          18.8000,  8.5000, 22.5000, 11.3000, 16.2000,  8.3000]],
#        dtype=torch.float64)
# label:
# tensor([[29.7000, 18.1000],
#         [19.6000,  5.8000]], dtype=torch.float64)
# input:
# tensor([[18.8000, 13.2000, 23.4000, 13.2000, 20.4000, 13.6000, 22.7000, 14.5000,
#          20.5000, 14.1000, 21.7000, 13.4000, 24.2000, 17.6000],
#         [11.1000,  3.6000, 10.8000,  8.2000, 10.7000,  6.1000, 11.9000,  6.1000,
#          10.4000,  6.3000,  9.7000,  6.4000,  8.4000,  7.1000]],
#        dtype=torch.float64)
# label:
# tensor([[26.1000, 18.0000],
#         [10.6000,  8.2000]], dtype=torch.float64)
# input:
# tensor([[ 1.3000, -4.1000, -2.5000, -6.9000, -5.2000, -8.1000, -0.9000, -6.9000,
#          -0.5000, -4.0000,  2.8000, -3.5000,  5.1000, -4.7000],
#         [26.5000, 16.3000, 26.0000, 16.4000, 20.4000, 13.2000, 19.4000, 12.7000,
#          23.1000, 12.1000, 26.4000, 14.4000, 26.8000, 18.2000]],
#        dtype=torch.float64)
# label:
# tensor([[ -4.6000, -12.5000],
#         [ 31.7000,  19.2000]], dtype=torch.float64)
# input:
# tensor([[10.1000,  2.6000,  6.4000,  0.7000,  8.1000,  2.4000, 10.1000,  4.8000,
#          11.9000,  7.7000, 10.0000,  4.1000,  4.8000,  3.3000],
#         [ 6.9000, -0.9000,  5.4000, -0.3000,  8.8000,  1.9000,  3.8000, -1.0000,
#           4.4000,  0.0000,  6.1000,  2.5000,  6.6000,  1.2000]],
#        dtype=torch.float64)
# label:
# tensor([[5.4000, 0.5000],
#         [9.7000, 0.9000]], dtype=torch.float64)
# input:
# tensor([[13.9000,  7.8000, 13.1000,  6.2000, 11.3000,  8.3000, 15.1000,  9.0000,
#          12.0000, 10.6000, 11.3000,  9.6000, 15.4000, 10.1000],
#         [31.1000, 20.2000, 26.7000, 19.2000, 26.5000, 18.6000, 28.2000, 19.4000,
#          29.0000, 19.3000, 30.0000, 20.5000, 29.7000, 21.0000]],
#        dtype=torch.float64)
# label:
# tensor([[15.7000,  8.2000],
#         [32.0000, 23.7000]], dtype=torch.float64)
# input:
# tensor([[18.0000,  9.8000, 20.7000, 10.6000, 21.3000, 11.5000, 21.5000,  9.2000,
#          21.1000, 13.4000, 18.9000, 11.2000, 20.4000, 13.7000],
#         [20.1000, 15.6000, 24.9000, 13.2000, 19.7000, 11.4000, 16.3000, 11.3000,
#          11.7000,  6.0000,  8.8000,  4.2000, 13.9000,  4.7000]],
#        dtype=torch.float64)
# label:
# tensor([[21.0000, 10.4000],
#         [10.6000,  5.9000]], dtype=torch.float64)
# input:
# tensor([[24.9000, 11.6000, 17.3000,  7.7000, 16.3000,  5.9000, 19.6000,  9.5000,
#          27.0000, 11.5000, 26.4000, 14.5000, 25.7000, 16.5000],
#         [12.3000,  5.8000,  8.8000,  4.5000, 12.8000,  4.4000, 16.5000,  5.8000,
#          26.5000, 11.7000, 16.7000,  8.1000, 26.8000,  7.9000]],
#        dtype=torch.float64)
# label:
# tensor([[24.6000, 15.1000],
#         [18.7000,  7.7000]], dtype=torch.float64)
# input:
# tensor([[15.8000,  6.7000, 12.9000,  6.7000, 14.5000,  6.0000, 21.9000,  8.1000,
#          13.9000,  7.6000, 16.7000,  6.0000, 18.1000, 10.9000],
#         [13.5000,  7.6000, 19.5000,  6.9000, 25.3000,  9.9000, 24.7000, 15.3000,
#          22.9000, 14.3000, 22.6000, 13.5000, 13.8000,  9.1000]],
#        dtype=torch.float64)
# label:
# tensor([[23.3000, 11.7000],
#         [14.1000,  6.4000]], dtype=torch.float64)
# input:
# tensor([[23.6000, 13.1000, 16.4000, 11.4000, 15.7000, 10.4000, 23.7000,  9.4000,
#          26.8000, 13.5000, 27.7000, 16.4000, 27.5000, 16.8000],
#         [33.9000, 25.2000, 34.7000, 21.3000, 29.8000, 20.7000, 22.3000, 17.3000,
#          23.6000, 17.3000, 27.4000, 16.8000, 21.5000, 13.7000]],
#        dtype=torch.float64)
# label:
# tensor([[26.3000, 17.3000],
#         [23.3000, 13.6000]], dtype=torch.float64)
# input:
# tensor([[20.0000,  9.5000, 20.5000, 11.3000, 19.7000, 13.5000, 25.1000, 11.5000,
#          27.7000, 13.2000, 20.2000, 16.3000, 20.9000, 16.3000],
#         [26.5000, 17.9000, 28.8000, 18.0000, 28.4000, 18.1000, 24.0000, 16.0000,
#          23.7000, 14.3000, 23.3000, 15.1000, 23.8000, 14.3000]],
#        dtype=torch.float64)
# label:
# tensor([[24.7000, 15.5000],
#         [29.1000, 16.1000]], dtype=torch.float64)
# input:
# tensor([[23.3000,  9.8000, 15.4000,  7.2000, 14.5000,  6.6000, 14.9000,  8.4000,
#          19.5000,  7.0000, 15.0500,  3.3000, 10.6000,  3.7000],
#         [11.9000,  7.4000, 15.0000,  9.5000, 18.1000, 10.0000, 17.9000, 10.3000,
#          22.0000, 11.9000, 24.5000, 13.5000, 16.6000, 11.0000]],
#        dtype=torch.float64)
# label:
# tensor([[ 7.4000,  4.9000],
#         [19.5000, 10.1000]], dtype=torch.float64)
# input:
# tensor([[19.1000, 13.9000, 16.5000, 13.4000, 19.8000, 14.9000, 18.3000, 13.8000,
#          19.6000, 16.0000, 20.2000, 14.8000, 22.8000, 16.7000],
#         [31.4000, 20.2000, 31.8000, 20.4000, 32.2000, 21.9000, 30.8000, 21.2000,
#          30.9000, 18.2000, 27.7000, 17.8000, 28.1000, 17.0000]],
#        dtype=torch.float64)
# label:
# tensor([[22.4000, 15.5000],
#         [27.3000, 15.8000]], dtype=torch.float64)
# input:
# tensor([[ 26.2000,  18.5000,  24.2000,  17.5000,  26.0000,  16.8000,  25.4000,
#           16.7000,  25.5000,  16.5000,  26.1000,  16.8000,  26.7000,  17.1000],
#         [ -4.3000, -18.5000,   0.7000,  -4.3000,  -0.5000,  -1.6000,   0.5000,
#           -2.4000,  -0.2000,  -3.8000,  -3.2000,  -7.2000,  -2.7000, -12.3000]],
#        dtype=torch.float64)
# label:
# tensor([[ 24.7250,  20.0000],
#         [ -9.7000, -16.3000]], dtype=torch.float64)
# input:
# tensor([[ 7.4000,  1.2000,  9.2000, -0.5000, 14.0000,  9.2000, 14.5000,  1.9000,
#           4.3000,  0.0000,  6.5000,  2.9000,  7.8000, -1.2000],
#         [15.9000, 10.3000, 14.8000,  7.8000, 15.8000,  7.1000, 18.2000, 10.2000,
#          18.9000,  9.9000, 20.4000,  9.0000, 15.2000,  8.2000]],
#        dtype=torch.float64)
# label:
# tensor([[ 4.4000, -0.9000],
#         [14.2000,  6.3000]], dtype=torch.float64)
# input:
# tensor([[  0.2000, -15.4000, -10.4000, -19.5000,  -3.5000, -11.6000,  -2.1000,
#          -10.8000,  -3.7000,  -8.4000,   0.0000,  -3.8500,   5.5000,   0.7000],
#         [  1.7000, -13.2000,   4.6000,  -4.5000,  -3.7000,  -6.8000,  -3.6000,
#          -12.5000,   2.0000,  -7.8000,   3.3000,  -0.3000,   2.6000,  -1.4000]],
#        dtype=torch.float64)
# label:
# tensor([[ 1.1000, -7.7000],
#         [ 3.0000,  0.4000]], dtype=torch.float64)
# input:
# tensor([[26.0000, 18.2000, 18.3000, 13.7000, 19.4000, 11.5000, 19.2000, 15.2000,
#          21.1000, 16.7000, 26.1000, 16.2000, 23.3000, 16.3000],
#         [23.7000, 18.4000, 25.8000, 16.1000, 27.8000, 17.7000, 29.1000, 18.9000,
#          26.5000, 18.4000, 28.8000, 17.4000, 23.2000, 14.7000]],
#        dtype=torch.float64)
# label:
# tensor([[25.6000, 16.2000],
#         [28.0000, 16.4000]], dtype=torch.float64)
# input:
# tensor([[ 7.7000,  1.3000,  7.1000,  0.3500,  6.5000, -0.6000,  1.4000, -2.3000,
#           2.8000, -2.0000,  2.4000, -1.9000,  1.7000, -0.8000],
#         [24.1000, 13.3000, 19.8000, 11.6000, 18.7000, 10.1000, 20.2000, 11.4000,
#          24.5000, 17.5000, 22.3000, 19.9000, 28.0000, 17.8000]],
#        dtype=torch.float64)
# label:
# tensor([[ 0.0000, -5.6000],
#         [18.0000, 10.3000]], dtype=torch.float64)
# input:
# tensor([[10.1000,  3.0000,  9.2000,  6.5000, 16.8000,  9.1000, 18.1000,  3.9000,
#           4.3000,  2.3000,  7.1000,  2.3000,  6.1000,  2.8000],
#         [ 8.6000,  1.0000,  9.1000,  6.4000,  7.1000, -1.7000, -0.3000, -6.1000,
#          -0.9000, -6.5000,  1.8000, -6.3000,  0.6000, -6.0000]],
#        dtype=torch.float64)
# label:
# tensor([[ 9.7000,  1.4000],
#         [ 2.1000, -4.9000]], dtype=torch.float64)
# input:
# tensor([[ 15.9000,   8.0000,  14.6000,   6.2000,  17.0000,   6.5000,  15.1000,
#            7.0000,  15.1000,  10.7000,  14.2000,   8.5000,  14.1000,   8.2000],
#         [ -2.2000,  -8.8000,  -1.3000,  -7.0000,   1.4000,  -4.2000,   1.3000,
#           -6.3000,   0.7000,  -6.1000,  -4.3000, -11.2000,  -2.3000, -10.8000]],
#        dtype=torch.float64)
# label:
# tensor([[19.6000, 10.3000],
#         [ 0.8000, -9.0000]], dtype=torch.float64)
# input:
# tensor([[ -9.6000, -15.3000,  -8.3000, -18.5000,  -3.6000,  -9.5000,  -3.7000,
#           -9.9000,  -7.0000, -14.3000,   2.0000, -14.0000,   5.9000,  -1.3000],
#         [ 13.1000,   8.6000,  11.4000,   8.5000,  16.5000,   8.3000,  18.2000,
#            7.2000,  12.7000,   9.1000,  12.6000,  10.1000,  20.9000,  11.9000]],
#        dtype=torch.float64)
# label:
# tensor([[ 4.2000, -3.1000],
#         [18.4000,  8.6000]], dtype=torch.float64)
# input:
# tensor([[13.3000,  3.5000, 11.3000,  6.0000,  6.0000,  1.3000,  2.6000, -6.8000,
#           1.4000, -7.1000,  6.4000, -2.1000, -1.5000, -5.2000],
#         [23.2000, 14.9000, 23.8000, 13.2000, 26.1000, 16.2000, 26.8000, 17.7000,
#          24.6000, 16.6000, 23.9000, 15.0000, 26.2000, 15.3000]],
#        dtype=torch.float64)
# label:
# tensor([[-0.4000, -5.8000],
#         [27.1000, 15.9000]], dtype=torch.float64)
# input:
# tensor([[ -0.8000,  -8.2000,  -6.1000,  -8.9000,  -0.9000,  -7.4000,   5.7000,
#           -2.1000,   3.9000,  -2.7000,   0.3000,  -9.1000,  -6.6000, -10.1000],
#         [ 33.2000,  21.1000,  24.0000,  16.4000,  26.7000,  15.5000,  27.6000,
#           13.5000,  22.8000,  14.6000,  26.6000,  13.2000,  28.9000,  15.1000]],
#        dtype=torch.float64)
# label:
# tensor([[ -2.6000, -13.3000],
#         [ 29.7000,  16.0000]], dtype=torch.float64)
# input:
# tensor([[ 6.2000,  3.7000, 13.1000,  2.1000, 11.4000,  2.7000, 12.3000,  4.1000,
#           9.2000,  1.7000, 12.7000,  1.4000, 15.8000,  3.8000],
#         [13.8000,  7.4000, 13.8000,  1.6000,  2.3000, -0.5000,  3.8000, -3.0000,
#           3.5000, -0.2000,  9.0000,  2.4000,  7.9000,  2.9000]],
#        dtype=torch.float64)
# label:
# tensor([[14.5000,  5.3000],
#         [ 7.0000,  3.2000]], dtype=torch.float64)
# input:
# tensor([[14.9000,  4.9000, 17.7000,  6.5000, 20.5000,  7.1000, 15.9000, 10.0000,
#          27.3000, 15.9000, 28.9000, 19.0000, 29.0000, 18.1000],
#         [23.6000, 19.0000, 25.5000, 16.9000, 25.9000, 14.3000, 27.8000, 15.9000,
#          26.7000, 19.1000, 25.1000, 20.2000, 26.4000, 19.6000]],
#        dtype=torch.float64)
# label:
# tensor([[26.9000, 17.7000],
#         [29.7000, 18.5000]], dtype=torch.float64)
# input:
# tensor([[27.5000, 19.2000, 21.8000, 17.3000, 25.9000, 16.5000, 27.6000, 16.3000,
#          25.3000, 15.2000, 22.6000, 12.9000, 24.8000, 14.3000],
#         [23.2000, 15.9000, 19.3000, 14.3000, 18.1000, 13.3000, 23.5000, 13.7000,
#          17.0000, 14.9000, 27.5000, 15.8000, 25.5000, 18.9000]],
#        dtype=torch.float64)
# label:
# tensor([[23.6000, 14.4000],
#         [26.5000, 18.0000]], dtype=torch.float64)
# input:
# tensor([[  4.9000,  -2.2000,  -0.2000,  -2.1000,  -0.3000,  -5.3000,  -5.3000,
#          -11.1000,  -2.1000, -10.3000,   1.8000,  -2.5000,   1.4000,  -4.8000],
#         [ -2.4000, -11.7000,   2.4000,  -7.4000,   8.0000,   1.5000,   2.9000,
#           -0.2000,   2.1000,  -3.2000,   2.9000,  -2.8000,   3.0000,  -5.5000]],
#        dtype=torch.float64)
# label:
# tensor([[ -4.7000, -11.2000],
#         [ -1.4000,  -7.5000]], dtype=torch.float64)
# input:
# tensor([[ 3.7000, -2.4000,  5.9000, -0.1000,  8.1000,  3.4000,  7.8000, -5.5000,
#          -5.3000, -8.8000, -0.8000, -8.2000, -6.1000, -8.9000],
#         [25.7000, 15.3000, 26.8000, 14.5000, 28.1000, 14.7000, 29.0000, 20.6000,
#          29.6000, 19.2000, 31.4000, 20.2000, 31.8000, 20.4000]],
#        dtype=torch.float64)
# label:
# tensor([[-0.9000, -7.4000],
#         [32.2000, 21.9000]], dtype=torch.float64)
# input:
# tensor([[27.9000, 19.8000, 28.4000, 18.2000, 26.6000, 19.6000, 27.0000, 17.9000,
#          26.8000, 17.3000, 26.4000, 19.7000, 28.7000, 18.5000],
#         [ 6.2000, -1.5000,  4.7000, -3.1000,  8.6000,  1.0000,  9.1000,  6.4000,
#           7.1000, -1.7000, -0.3000, -6.1000, -0.9000, -6.5000]],
#        dtype=torch.float64)
# label:
# tensor([[25.4000, 17.9000],
#         [ 1.8000, -6.3000]], dtype=torch.float64)
# input:
# tensor([[29.0000, 19.9000, 24.4000, 19.6000, 21.2000, 17.5000, 23.8000, 17.0000,
#          24.5000, 16.5000, 24.1000, 18.1000, 22.1000, 17.5000],
#         [24.4000, 14.5000, 28.9000, 15.6000, 30.5000, 17.2000, 34.2000, 21.3000,
#          33.0000, 23.1000, 33.2000, 22.9000, 34.1000, 24.6000]],
#        dtype=torch.float64)
# label:
# tensor([[24.5500, 18.5000],
#         [26.5000, 19.8000]], dtype=torch.float64)
# input:
# tensor([[ 27.1000,  18.7000,  27.5000,  19.4000,  24.3000,  18.3000,  26.5000,
#           17.9000,  28.8000,  19.8000,  25.6000,  18.4000,  21.9000,  14.5000],
#         [ -8.1000, -15.6000,  -4.7000, -10.5000,  -2.9000,  -8.6000,   2.9000,
#           -4.9000,   2.8000,  -6.2000,   1.4000,  -9.2000,   6.9000,   1.2000]],
#        dtype=torch.float64)
# label:
# tensor([[20.4000, 11.8000],
#         [10.6000,  3.9000]], dtype=torch.float64)
# input:
# tensor([[21.0000, 10.9000, 24.3000, 11.9000, 25.6000, 15.2000, 28.8000, 15.2000,
#          30.5000, 16.8000, 31.8000, 18.6000, 31.7000, 19.1000],
#         [30.5000, 20.1000, 24.1000, 15.5000, 15.5000, 10.6000, 17.2000,  6.3000,
#          19.3000, 10.8000, 15.0000,  8.8000, 16.0000,  7.5000]],
#        dtype=torch.float64)
# label:
# tensor([[26.7000, 14.9000],
#         [20.8000,  9.2000]], dtype=torch.float64)
# input:
# tensor([[-3.6000, -7.7000, -2.4000, -8.3000,  1.8000, -7.5000,  5.0000,  0.1000,
#           4.9000,  1.7000,  3.6000,  1.5000,  4.3000,  2.0000],
#         [21.9000, 12.1000, 24.1000, 13.1000, 27.2000, 16.4000, 32.4000, 19.0000,
#          30.2000, 20.2000, 23.7000, 18.4000, 25.8000, 16.1000]],
#        dtype=torch.float64)
# label:
# tensor([[ 4.7000,  1.5000],
#         [27.8000, 17.7000]], dtype=torch.float64)
# input:
# tensor([[  2.8000,  -2.5000,   3.4000,  -5.7000,  -4.3000,  -8.9000,  -1.9000,
#           -9.5000,   1.1000,  -8.4000,  -3.0000, -10.6000,   4.8000,  -7.2000],
#         [ -2.9000,  -8.6000,   2.9000,  -4.9000,   2.8000,  -6.2000,   1.4000,
#           -9.2000,   6.9000,   1.2000,  10.6000,   3.9000,   4.9000, -14.0000]],
#        dtype=torch.float64)
# label:
# tensor([[ 10.2000,   3.0000],
#         [ -6.1000, -16.5000]], dtype=torch.float64)
# input:
# tensor([[30.1000, 22.3000, 25.5000, 19.2000, 19.5000, 14.7000, 22.7000, 15.2000,
#          22.6000, 12.5000, 21.1000, 11.8000, 20.8000, 10.6000],
#         [21.8000, 17.3000, 25.9000, 16.5000, 27.6000, 16.3000, 25.3000, 15.2000,
#          22.6000, 12.9000, 24.8000, 14.3000, 23.6000, 14.4000]],
#        dtype=torch.float64)
# label:
# tensor([[27.0000, 12.0000],
#         [25.2000, 12.6000]], dtype=torch.float64)
# input:
# tensor([[28.0000, 19.5000, 26.6000, 18.6000, 30.0000, 18.4000, 25.1000, 17.1000,
#          22.7000, 15.4000, 19.3000,  7.4000, 17.3000,  8.1000],
#         [22.2000, 15.0000, 15.2000,  5.9000, 13.9000,  4.6000, 17.0000, 10.1000,
#          17.7000, 11.4000, 14.2000,  7.4000, 14.6000,  5.5000]],
#        dtype=torch.float64)
# label:
# tensor([[20.3000, 11.4000],
#         [13.8000,  5.8000]], dtype=torch.float64)
# input:
# tensor([[ 21.8000,  11.3000,  22.2000,  14.1000,  26.4000,  16.6000,  28.2000,
#           18.6000,  25.9000,  20.0000,  26.7000,  19.8000,  30.9000,  20.9000],
#         [ -9.7000, -16.5000,  -9.3000, -14.7000,  -6.7000, -12.0000,  -3.6000,
#          -10.4000,  -1.9000,  -8.9000,  -2.6000,  -6.0000,  -6.0000, -11.4000]],
#        dtype=torch.float64)
# label:
# tensor([[ 33.3000,  23.1000],
#         [ -8.6000, -14.0000]], dtype=torch.float64)
# input:
# tensor([[ -2.9000,  -7.5000,  -0.3000,  -8.8000,  -5.3000, -10.1000,  -1.5000,
#           -7.3000,   2.6000,  -4.6000,   8.2000,   1.8000,   3.0000,  -0.8000],
#         [ 17.4000,   7.9000,  18.2000,   9.0000,  19.0000,  10.9000,  19.8000,
#            9.8000,  19.3000,   9.6000,  16.5000,  11.7000,  17.6000,   8.8000]],
#        dtype=torch.float64)
# label:
# tensor([[ 0.0000, -1.1000],
#         [18.0000,  9.2000]], dtype=torch.float64)
# input:
# tensor([[22.3000,  5.9000,  8.9000,  3.8000, 15.3000,  4.9000, 17.3000,  5.2000,
#          18.1000,  6.0000, 18.5000,  4.6000, 13.0000,  3.6000],
#         [18.5000, 16.0000, 22.9000, 14.9000, 19.4000,  9.9000, 12.2000,  7.1000,
#           9.0000,  4.0000, 13.0000,  4.2000, 14.7000,  8.4000]],
#        dtype=torch.float64)
# label:
# tensor([[12.6000,  3.8000],
#         [12.2000,  5.1000]], dtype=torch.float64)
# input:
# tensor([[24.8000, 14.6000, 24.2000, 15.2000, 19.3000, 16.0000, 16.6000, 14.9000,
#          18.4000, 15.2000, 22.2000, 15.0000, 15.2000,  5.9000],
#         [24.2000, 15.8000, 20.5000, 15.0000, 23.6000, 15.5000, 25.0000, 14.9000,
#          26.2000, 13.1000, 24.0000, 12.1000, 18.4000, 10.6000]],
#        dtype=torch.float64)
# label:
# tensor([[13.9000,  4.6000],
#         [20.9000, 11.7000]], dtype=torch.float64)
# input:
# tensor([[ 0.8000, -6.0000,  5.4000, -1.3000,  5.2000,  1.4000,  6.4000,  1.0000,
#           7.0000, -0.6000, 13.3000,  3.5000, 11.3000,  6.0000],
#         [10.4000,  5.2000, 11.3000,  5.6000, 14.8000,  9.1000, 12.8000,  5.6000,
#           9.9000,  3.2000, 11.1000,  2.6000, 15.7000,  8.0000]],
#        dtype=torch.float64)
# label:
# tensor([[ 6.0000,  1.3000],
#         [14.5000,  5.8000]], dtype=torch.float64)
# input:
# tensor([[ -6.6000, -10.1000,  -2.6000, -13.3000,  -2.7000,  -6.3000,  -2.1000,
#           -6.5000,  -1.8000,  -6.8000,  -2.5000,  -9.7000,   0.2000,  -8.0000],
#         [ 24.2000,  13.0000,  18.1000,  10.5000,  20.6000,  12.5000,  22.4000,
#           12.0000,  24.0000,  13.8000,  22.0000,  16.5000,  20.7000,  14.6000]],
#        dtype=torch.float64)
# label:
# tensor([[ 5.1000, -0.1000],
#         [19.1000, 12.2000]], dtype=torch.float64)
# input:
# tensor([[ 8.3000,  2.0000,  7.7000,  1.3000,  7.1000,  0.3500,  6.5000, -0.6000,
#           1.4000, -2.3000,  2.8000, -2.0000,  2.4000, -1.9000],
#         [25.7000, 18.7000, 31.3000, 20.6000, 31.7000, 21.8000, 33.1000, 19.7000,
#          26.8000, 18.5000, 26.9000, 17.4000, 27.4000, 17.6000]],
#        dtype=torch.float64)
# label:
# tensor([[ 1.7000, -0.8000],
#         [31.5000, 19.2000]], dtype=torch.float64)
# input:
# tensor([[ 5.4000, -0.5000,  6.7000,  0.6000,  7.1000,  3.0000,  9.4000,  1.3000,
#          12.5000,  4.3000, 14.5000,  6.0000, 11.3000,  3.3000],
#         [13.1000,  2.7000, 10.7000,  1.9000, 12.3000,  2.7000, 17.7000,  6.3000,
#          19.3000,  9.1000, 12.3000,  8.7000, 20.6000, 11.6000]],
#        dtype=torch.float64)
# label:
# tensor([[21.2000,  5.3000],
#         [21.2000, 13.5000]], dtype=torch.float64)
# input:
# tensor([[  1.3000,  -0.6000,   2.2000,  -2.3000,   1.9000,  -6.5000,  -6.5000,
#          -14.1000,  -2.0000, -15.0000,   0.1000,  -5.2000,   2.1000,  -4.7000],
#         [ 14.5000,   7.9000,  18.5000,  11.5000,  18.9000,   9.6000,  24.5000,
#           13.7000,  26.3000,  14.8000,  21.4000,  14.9000,  22.1000,  15.5000]],
#        dtype=torch.float64)
# label:
# tensor([[ 4.1000,  2.1000],
#         [19.8000, 10.5000]], dtype=torch.float64)
# input:
# tensor([[14.1000,  7.3000, 12.8000,  7.4000, 18.0000,  9.8000, 20.7000, 10.6000,
#          21.3000, 11.5000, 21.5000,  9.2000, 21.1000, 13.4000],
#         [20.8000, 12.6000, 22.0000, 13.8000, 21.6000, 18.4000, 22.7000, 18.5000,
#          22.6000, 10.5000, 15.9000, 10.3000, 14.8000,  7.8000]],
#        dtype=torch.float64)
# label:
# tensor([[18.9000, 11.2000],
#         [15.8000,  7.1000]], dtype=torch.float64)
# input:
# tensor([[20.5000, 12.0000, 25.5000, 14.7000, 24.4000, 17.3000, 27.2000, 16.3000,
#          25.5000, 15.3000, 22.5000, 12.2000, 26.2000, 13.6000],
#         [26.7000, 19.1000, 25.1000, 20.2000, 26.4000, 19.6000, 29.7000, 18.5000,
#          28.6000, 18.5000, 30.5000, 19.8000, 29.3000, 17.4000]],
#        dtype=torch.float64)
# label:
# tensor([[29.9000, 17.4000],
#         [29.8000, 20.5000]], dtype=torch.float64)
# input:
# tensor([[30.9000, 20.9000, 33.3000, 23.1000, 32.7000, 21.4000, 27.8000, 18.0000,
#          25.9000, 15.3000, 24.9000, 16.8000, 20.7000, 15.0000],
#         [ 9.4000,  3.1000, 18.5000,  2.4000, 15.1000,  6.6000, 16.1000,  7.7000,
#          19.8000, 11.3000, 22.5000,  9.1000, 23.7000, 14.7000]],
#        dtype=torch.float64)
# label:
# tensor([[26.4000, 14.1000],
#         [23.5000, 13.6000]], dtype=torch.float64)
# input:
# tensor([[ 15.7000,  11.8000,  19.2000,  11.8000,  18.6000,  11.3000,  20.4000,
#           12.7000,  23.1000,  13.2000,  23.3000,  15.4000,  24.3000,  13.4000],
#         [ -5.8000,  -9.4000,  -8.4000, -14.5000, -14.3000, -19.2000,  -7.1000,
#          -22.3000,   0.3000,  -7.2000,   1.4000,  -1.7000,   2.4000, -15.8000]],
#        dtype=torch.float64)
# label:
# tensor([[ 23.9000,  14.7000],
#         [-15.8000, -22.2000]], dtype=torch.float64)
# input:
# tensor([[23.8000, 14.4000, 26.9000, 14.7000, 26.0000, 18.7000, 26.7000, 18.8000,
#          23.6000, 18.1000, 26.0000, 16.9000, 22.2000, 14.8000],
#         [24.6000, 14.4000, 23.0000, 17.4000, 22.7000, 15.7000, 19.6000, 12.8000,
#          15.5000, 12.2000, 24.2000, 14.3000, 19.3000, 15.6000]],
#        dtype=torch.float64)
# label:
# tensor([[25.8000, 13.2000],
#         [24.1000, 14.8000]], dtype=torch.float64)
# input:
# tensor([[30.0000, 20.2000, 31.4000, 22.5000, 31.7000, 23.5000, 35.4000, 24.7000,
#          33.9000, 25.2000, 34.7000, 21.3000, 29.8000, 20.7000],
#         [21.8000, 15.4000, 21.6000, 14.0000, 23.6000, 14.8000, 25.1000, 15.1000,
#          27.5000, 17.1000, 25.8000, 17.4000, 26.8000, 19.7000]],
#        dtype=torch.float64)
# label:
# tensor([[22.3000, 17.3000],
#         [26.2000, 18.5000]], dtype=torch.float64)
# input:
# tensor([[33.0000, 19.7000, 26.4000, 19.0000, 27.1000, 18.7000, 27.5000, 19.4000,
#          24.3000, 18.3000, 26.5000, 17.9000, 28.8000, 19.8000],
#         [20.8000, 15.8000, 30.8000, 16.6000, 21.7000, 15.3000, 17.4000, 10.9000,
#          16.7000, 10.5000, 12.6000,  5.1000, 11.9000,  5.8000]],
#        dtype=torch.float64)
# label:
# tensor([[25.6000, 18.4000],
#         [13.8000,  8.7000]], dtype=torch.float64)
# input:
# tensor([[11.3000,  8.3000, 15.1000,  9.0000, 12.0000, 10.6000, 11.3000,  9.6000,
#          15.4000, 10.1000, 15.7000,  8.2000, 10.5000,  6.3000],
#         [ 3.8000,  1.5000, 10.9000,  2.6000, 13.1000,  1.0000, 10.5000,  0.8000,
#          14.6000,  3.2000,  6.7000,  1.8000,  6.9000,  1.4000]],
#        dtype=torch.float64)
# label:
# tensor([[11.0000,  5.9000],
#         [ 8.5000,  1.5000]], dtype=torch.float64)
# input:
# tensor([[15.1000,  8.8000,  8.8000,  4.8000,  9.1000,  2.7000,  9.4000,  2.3000,
#          10.6000,  3.1000,  7.2000,  4.3000,  9.1000,  2.4000],
#         [18.3000,  8.3000, 14.2000,  6.5000,  8.6000,  3.6000,  9.4000,  3.1000,
#          10.6000,  3.0000, 14.8000,  8.7000, 14.0000,  4.8000]],
#        dtype=torch.float64)
# label:
# tensor([[9.6667, 6.1000],
#         [9.8000, 3.6000]], dtype=torch.float64)
# input:
# tensor([[-11.1000, -15.0000,  -9.1000, -18.4000,  -9.9000, -14.7000,  -7.4000,
#          -13.3000,  -1.8000,  -9.7000,  -0.7000,  -9.3000,   3.8000,  -1.4000],
#         [  9.4000,   3.6000,   6.7000,   1.5000,  10.6000,   3.4000,   8.6000,
#            3.5000,   6.6000,  -1.8000,   1.9000,  -3.8000,   3.9000,  -4.3000]],
#        dtype=torch.float64)
# label:
# tensor([[ 7.1000,  1.3000],
#         [10.2000,  1.5000]], dtype=torch.float64)
# input:
# tensor([[28.1000, 19.9000, 30.1000, 19.7000, 31.6000, 20.9000, 26.4000, 20.8000,
#          29.1000, 21.4000, 25.9000, 18.9000, 23.0000, 15.3000],
#         [24.6000, 11.7000, 19.1000, 12.8000, 22.5000, 12.6000, 24.9000, 11.6000,
#          17.3000,  7.7000, 16.3000,  5.9000, 19.6000,  9.5000]],
#        dtype=torch.float64)
# label:
# tensor([[23.8000, 14.0000],
#         [27.0000, 11.5000]], dtype=torch.float64)
# input:
# tensor([[  2.7000,  -4.0000,  -0.7000,  -5.7000,   0.2000,  -6.8000,   7.1000,
#           -1.2000,   8.3000,  -0.1000,   5.0000,  -3.0000,   0.8000,  -5.1000],
#         [ -3.0000, -13.8000,  -8.7000, -16.0000,  -1.7000, -12.5000,  -6.7000,
#          -12.5000,   0.1000,  -9.6000,   7.3000,   0.1000,   2.3000,  -2.8000]],
#        dtype=torch.float64)
# label:
# tensor([[ 1.4000, -5.9000],
#         [ 3.5000, -3.3000]], dtype=torch.float64)
# input:
# tensor([[ -6.1000, -10.3000,  -3.8000, -10.3000,  -3.0000,  -9.1000,   0.9000,
#           -4.7000,   0.8000,  -2.9000,   2.3000,  -4.5000,  12.3000,   1.8000],
#         [  9.3000,   6.4000,   8.3000,   2.0000,   7.7000,   1.3000,   7.1000,
#            0.3500,   6.5000,  -0.6000,   1.4000,  -2.3000,   2.8000,  -2.0000]],
#        dtype=torch.float64)
# label:
# tensor([[11.6000,  5.4000],
#         [ 2.4000, -1.9000]], dtype=torch.float64)
# input:
# tensor([[ 25.9000,  15.3000,  24.9000,  16.8000,  20.7000,  15.0000,  26.4000,
#           14.1000,  25.3000,  16.4000,  29.4000,  18.2000,  32.9000,  21.2000],
#         [ -3.4000, -14.4000, -14.3000, -24.7000,  -9.6000, -22.4000,   0.0000,
#           -9.6000,   0.5000,  -0.8000,   0.0000,  -9.3000,  -3.0000, -11.0000]],
#        dtype=torch.float64)
# label:
# tensor([[33.6000, 19.4000],
#         [ 8.1000, -3.3000]], dtype=torch.float64)
# input:
# tensor([[17.1000, 13.2000, 19.6000, 14.3000, 19.6000,  9.7000, 17.4000,  7.9000,
#          18.2000,  9.0000, 19.0000, 10.9000, 19.8000,  9.8000],
#         [ 3.8000, -3.0000,  3.5000, -0.2000,  9.0000,  2.4000,  7.9000,  2.9000,
#           7.0000,  3.2000,  6.4000,  4.8000,  7.3000,  1.9000]],
#        dtype=torch.float64)
# label:
# tensor([[19.3000,  9.6000],
#         [ 5.1000,  0.0000]], dtype=torch.float64)
# input:
# tensor([[28.9000, 18.5000, 28.8000, 17.6000, 26.2000, 20.8000, 28.5000, 21.4000,
#          27.4000, 21.8000, 28.9000, 20.9000, 30.7000, 23.3000],
#         [ 7.0000,  1.9000, 10.6000,  5.6000,  5.7000,  4.0000,  6.7000,  2.1000,
#          10.1000,  4.3000,  6.4000,  0.0000,  1.3000, -4.1000]],
#        dtype=torch.float64)
# label:
# tensor([[29.6000, 20.6000],
#         [-2.5000, -6.9000]], dtype=torch.float64)
# input:
# tensor([[22.8000, 12.4000, 17.6000, 15.0000, 24.3000, 15.9000, 22.7000, 14.5000,
#          22.0000, 14.9000, 24.0000, 15.0000, 23.9000, 12.2000],
#         [ 6.7000,  1.5000, 10.6000,  3.4000,  8.6000,  3.5000,  6.6000, -1.8000,
#           1.9000, -3.8000,  3.9000, -4.3000, 10.2000,  1.5000]],
#        dtype=torch.float64)
# label:
# tensor([[26.5000, 16.3000],
#         [11.5000,  5.9000]], dtype=torch.float64)
# input:
# tensor([[23.7000, 13.8000, 18.6000, 15.7000, 21.3000, 17.4000, 26.4000, 16.8000,
#          22.6000, 15.6000, 26.6000, 15.1000, 24.4000, 13.9000],
#         [ 8.1000,  5.9000,  6.7000,  5.1000, 15.0000,  6.2000, 12.6000,  8.0000,
#          11.8000,  7.7000, 14.5000,  5.9000, 13.6000,  5.3000]],
#        dtype=torch.float64)
# label:
# tensor([[26.1000, 14.7000],
#         [14.1000,  7.3000]], dtype=torch.float64)
# input:
# tensor([[19.4000, 11.7000, 21.0000, 10.9000, 24.3000, 11.9000, 25.6000, 15.2000,
#          28.8000, 15.2000, 30.5000, 16.8000, 31.8000, 18.6000],
#         [28.5000, 16.9000, 32.5000, 18.5000, 33.2000, 21.1000, 24.0000, 16.4000,
#          26.7000, 15.5000, 27.6000, 13.5000, 22.8000, 14.6000]],
#        dtype=torch.float64)
# label:
# tensor([[31.7000, 19.1000],
#         [26.6000, 13.2000]], dtype=torch.float64)
# input:
# tensor([[ 9.0000, -3.5000, 17.4000,  4.0000,  6.4000,  1.8000,  5.7000,  1.3000,
#           4.7000,  0.6000,  4.0000,  0.9000,  8.4000, -4.4000],
#         [30.9000, 19.9000, 28.2000, 19.7000, 30.8000, 18.2000, 26.8000, 21.0000,
#          26.6000, 19.6000, 28.8000, 17.7000, 28.9000, 17.8000]],
#        dtype=torch.float64)
# label:
# tensor([[-1.3000, -7.6000],
#         [32.0000, 19.6000]], dtype=torch.float64)
# input:
# tensor([[ 9.4000,  0.6000,  9.3000,  2.8000, 10.1000,  1.2000,  9.9000,  6.3000,
#          12.7000,  6.5000, 15.7000,  8.0000, 12.1000,  4.1000],
#         [16.3000,  7.6000, 20.6000,  8.9000, 23.3000,  9.8000, 15.4000,  7.2000,
#          14.5000,  6.6000, 14.9000,  8.4000, 19.5000,  7.0000]],
#        dtype=torch.float64)
# label:
# tensor([[10.2000,  2.4000],
#         [15.0500,  3.3000]], dtype=torch.float64)
# input:
# tensor([[32.9000, 21.2000, 33.6000, 19.4000, 31.1000, 19.5000, 30.4000, 17.2000,
#          28.2000, 19.2000, 34.5000, 20.3000, 26.8000, 21.9000],
#         [21.7000, 13.9000, 24.1000, 14.0000, 21.7000, 16.9000, 22.0000, 16.8000,
#          23.1000, 17.9000, 24.8000, 17.9000, 22.5000, 18.6000]],
#        dtype=torch.float64)
# label:
# tensor([[36.0000, 21.7000],
#         [23.1000, 17.2000]], dtype=torch.float64)
# input:
# tensor([[ 7.5000,  3.5000,  6.5000, -0.1000,  4.9000, -2.7000,  6.1000, -1.1000,
#           1.6000, -4.2000,  4.7000, -1.1000,  6.9000,  0.0000],
#         [ 9.0000,  5.6000, 15.2000,  4.6000,  4.6000,  1.3000,  3.7500,  1.3000,
#           2.9000, -3.3000, -1.8000, -5.5000,  7.9000, -3.1000]],
#        dtype=torch.float64)
# label:
# tensor([[ 7.8000,  1.3000],
#         [12.0000,  4.5000]], dtype=torch.float64)
# input:
# tensor([[21.1000, 14.0000, 22.8000, 11.4000, 24.0000, 13.3000, 26.7000, 15.7000,
#          26.4000, 17.7000, 28.1000, 16.9000, 21.1000, 14.7000],
#         [ 7.1000, -1.7000, -0.3000, -6.1000, -0.9000, -6.5000,  1.8000, -6.3000,
#           0.6000, -6.0000,  2.1000, -4.9000,  2.0000,  0.5000]],
#        dtype=torch.float64)
# label:
# tensor([[22.5000, 15.7000],
#         [ 1.9000, -6.9000]], dtype=torch.float64)
# input:
# tensor([[ 15.4000,   4.3000,  13.9000,   5.9000,   5.9000,  -2.1000,  -1.5000,
#           -5.8000,   0.8000,  -6.7000,   2.5000,  -3.6000,   3.1000,  -2.5000],
#         [ -1.4000,  -9.2000,  -6.2000, -12.5000, -12.4000, -15.0000,  -8.8000,
#          -15.8000,  -7.8000, -13.2000,  -6.4000, -13.7000,  -3.6000,  -9.6000]],
#        dtype=torch.float64)
# label:
# tensor([[  0.2000,  -9.7000],
# ...
#        dtype=torch.float64)
# label:
# tensor([[28.0000, 16.8000],
#         [27.0000, 15.7000]], dtype=torch.float64)
# input:
# tensor([[15.4000,  3.9000,  9.9000,  4.0000,  6.7000,  3.2000, 11.0000,  1.7000,
#           5.9000, -2.2000,  0.9000, -3.3000,  8.5000, -0.5000],
#         [22.4000, 16.4000, 23.9000, 16.4000, 22.8000, 17.5000, 24.2000, 15.4000,
#          22.8000, 14.0000, 24.2000, 12.6000, 24.4000, 15.7000]],
#        dtype=torch.float64)
# label:
# tensor([[12.7000,  2.1000],
#         [21.2000, 15.1000]], dtype=torch.float64)
# input:
# tensor([[ 6.7000,  2.1000, 10.1000,  4.3000,  6.4000,  0.0000,  1.3000, -4.1000,
#          -2.5000, -6.9000, -5.2000, -8.1000, -0.9000, -6.9000],
#         [36.0000, 21.7000, 27.8000, 21.2000, 28.0000, 18.6000, 27.1000, 17.3000,
#          28.0000, 18.4000, 28.9000, 18.8000, 31.3000, 18.2000]],
#        dtype=torch.float64)
# label:
# tensor([[-0.5000, -4.0000],
#         [32.0000, 21.3000]], dtype=torch.float64)
# input:
# tensor([[13.5000,  7.3000,  9.7000,  2.3000,  7.0000,  1.5000, 10.7000,  3.7000,
#           7.5000,  1.2000,  4.9000,  1.5000,  6.6000,  0.9000],
#         [21.6000,  8.4000, 19.9000, 15.8000, 20.5000, 12.9000, 20.5000, 11.8000,
#          31.3000, 18.0000, 30.5000, 20.1000, 24.1000, 15.5000]],
#        dtype=torch.float64)
# label:
# tensor([[ 9.6000,  2.8000],
#         [15.5000, 10.6000]], dtype=torch.float64)
# input:
# tensor([[19.8000, 10.7000, 12.0000,  2.8000,  9.5000,  2.0000, 17.9000,  7.0000,
#          19.4000, 12.5000, 14.4000,  7.1000, 12.1000,  4.3000],
#         [10.1000, -0.7000, 12.5000,  3.1000, 12.8000,  5.2000, 12.8000,  5.0000,
#          13.8000,  6.5000, 11.5000,  4.7000, 17.6000,  7.3000]],
#        dtype=torch.float64)
# label:
# tensor([[16.1000,  7.3000],
#         [15.2000,  1.2000]], dtype=torch.float64)
# input:
# tensor([[ 24.1000,  12.6000,  24.1000,  13.2000,  28.0000,  16.3000,  20.5000,
#           15.3000,  23.3000,  14.8000,  21.7000,  13.9000,  24.1000,  14.0000],
#         [ -4.3000, -14.7000,  -1.1000,  -5.1000,   4.0000,  -7.0000,  -7.0000,
#          -17.0000,  -7.1000, -12.7000,  -7.4000, -13.3000,  -3.0000, -10.7000]],
#        dtype=torch.float64)
# label:
# tensor([[21.7000, 16.9000],
#         [-2.0000, -6.1000]], dtype=torch.float64)
# input:
# tensor([[ 3.0000,  0.4000,  4.2000,  0.5000,  2.1000,  0.5000,  4.0000, -0.5000,
#          -0.5000, -5.7000, -2.3000, -7.9000, -2.8000, -7.3000],
#         [22.5000, 13.4000, 14.9000, 12.1000, 18.7000, 13.6000, 16.0000,  9.2000,
#          13.6000,  7.8000, 13.2000,  5.6000, 13.8000,  6.1000]],
#        dtype=torch.float64)
# label:
# tensor([[ 0.4000, -6.8000],
#         [14.5000,  6.3000]], dtype=torch.float64)
# input:
# tensor([[ 9.3000,  4.5000, 12.8000,  4.0000, 15.9000,  6.1000, 22.5000,  6.9000,
#          12.2000,  4.7000, 10.6000,  5.1000, 13.8000,  3.7000],
#         [21.8000, 12.3000, 19.8000,  6.3000, 14.7000,  5.8000, 18.8000, 10.3000,
#          21.5000, 17.5000, 20.1000, 15.6000, 24.9000, 13.2000]],
#        dtype=torch.float64)
# label:
# tensor([[ 5.9000, -0.1000],
#         [19.7000, 11.4000]], dtype=torch.float64)
# input:
# tensor([[ 2.6000, -1.4000,  3.0000,  0.4000,  4.2000,  0.5000,  2.1000,  0.5000,
#           4.0000, -0.5000, -0.5000, -5.7000, -2.3000, -7.9000],
#         [26.9000, 17.2000, 28.4000, 18.4000, 23.7000, 16.6000, 23.3000, 15.7000,
#          22.1000, 13.0000, 24.7000, 14.6000, 27.8000, 16.6000]],
#        dtype=torch.float64)
# label:
# tensor([[-2.8000, -7.3000],
#         [29.5000, 20.2000]], dtype=torch.float64)
# input:
# tensor([[20.8000, 12.3000, 18.1000,  9.9000, 15.2000,  7.3000, 15.7000,  6.0000,
#          20.2000, 11.3000, 18.4000,  9.8000, 16.6000,  8.4000],
#         [12.4000,  5.4000, 14.7000,  5.0000, 16.2000,  6.9000,  9.3000,  3.5000,
#          10.7000,  2.1000, 13.8000,  8.3000, 10.7000,  7.9000]],
#        dtype=torch.float64)
# label:
# tensor([[18.1000, 10.3000],
#         [18.1000, 10.1000]], dtype=torch.float64)
# input:
# tensor([[27.1000, 15.9000, 25.9000, 17.4000, 24.0000, 17.1000, 24.7000, 18.0000,
#          28.2000, 19.0000, 23.9000, 19.5000, 27.9000, 19.3000],
#         [ 1.5000, -5.6000,  0.9000, -6.6000,  3.9000, -3.7000,  6.4000,  1.1000,
#           5.9000,  0.0000,  4.0000, -2.4000,  0.9000, -4.3000]],
#        dtype=torch.float64)
# label:
# tensor([[26.9000, 20.3000],
#         [ 5.3000, -1.2000]], dtype=torch.float64)
# input:
# tensor([[ 6.6000, -3.0000,  4.6000, -3.3000,  7.5000,  3.5000,  6.5000, -0.1000,
#           4.9000, -2.7000,  6.1000, -1.1000,  1.6000, -4.2000],
#         [-0.2000, -4.7000,  3.1000, -1.6000,  2.1000,  0.1500,  7.0000,  1.9000,
#          10.6000,  5.6000,  5.7000,  4.0000,  6.7000,  2.1000]],
#        dtype=torch.float64)
# label:
# tensor([[ 4.7000, -1.1000],
#         [10.1000,  4.3000]], dtype=torch.float64)
# input:
# tensor([[ 3.5000, -2.9000, -0.7000, -4.8000,  4.2000, -3.3000,  6.5000,  0.4000,
#           7.2000,  0.9000,  8.6000,  3.7000, 13.1000,  3.8000],
#         [18.9000, 11.3000, 22.4000, 10.5000, 21.5000, 11.0000, 28.4000, 13.4000,
#          28.0000, 19.5000, 26.6000, 18.6000, 30.0000, 18.4000]],
#        dtype=torch.float64)
# label:
# tensor([[ 6.3000,  0.0000],
#         [25.1000, 17.1000]], dtype=torch.float64)
# input:
# tensor([[11.5000,  4.7000, 17.6000,  7.3000, 15.2000,  1.2000,  2.7000, -2.6000,
#           1.4000, -2.5000,  2.9000, -2.0000,  2.3000, -2.0000],
#         [ 5.1000, -0.1000,  7.0000,  1.6000,  1.7000, -2.0000,  2.3000, -0.8000,
#           1.3000, -7.6000,  6.4000, -6.8000,  9.9000,  2.9000]],
#        dtype=torch.float64)
# label:
# tensor([[4.4000, 2.3000],
#         [9.9000, 1.8000]], dtype=torch.float64)
# input:
# tensor([[19.6000,  6.6000, 16.4000,  6.1000,  7.2000,  0.7000,  5.3000,  0.1000,
#           8.6000,  2.4000,  4.8000,  2.0000, 14.6000,  0.3000],
#         [28.4000, 18.4000, 23.7000, 16.6000, 23.3000, 15.7000, 22.1000, 13.0000,
#          24.7000, 14.6000, 27.8000, 16.6000, 29.5000, 20.2000]],
#        dtype=torch.float64)
# label:
# tensor([[10.1000, -1.6000],
#         [22.3000, 17.3000]], dtype=torch.float64)
# input:
# tensor([[18.2000, 13.2000, 24.1000, 13.3000, 19.8000, 11.6000, 18.7000, 10.1000,
#          20.2000, 11.4000, 24.5000, 17.5000, 22.3000, 19.9000],
#         [15.0000,  7.9000, 10.3000,  5.8000, 12.8000,  6.0000,  6.1000,  0.4000,
#           7.5000, -0.3000,  9.1000,  0.5000, 10.7000,  2.0000]],
#        dtype=torch.float64)
# label:
# tensor([[28.0000, 17.8000],
#         [ 8.6000,  5.6000]], dtype=torch.float64)
# input:
# tensor([[  4.7000,  -3.4000,  -2.5000,  -5.2000,  -4.7000, -10.4000,  -1.9000,
#           -6.5000,  -2.7000,  -6.9000,   1.5000,  -4.1000,  -1.2000,  -5.2000],
#         [  8.7000,   4.8000,  12.3000,   6.0000,   8.5000,   4.9000,   5.4000,
#           -0.5000,   6.7000,   0.6000,   7.1000,   3.0000,   9.4000,   1.3000]],
#        dtype=torch.float64)
# label:
# tensor([[ -4.9000, -10.3000],
#         [ 12.5000,   4.3000]], dtype=torch.float64)
# input:
# tensor([[ 9.4000,  3.1000, 10.6000,  3.0000, 14.8000,  8.7000, 14.0000,  4.8000,
#           9.8000,  3.6000,  7.1000,  1.6000, 11.1000,  3.6000],
#         [33.8000, 21.4000, 34.5000, 24.3000, 28.4000, 22.7000, 34.2000, 21.0000,
#          38.2000, 24.9000, 32.5000, 22.7000, 33.4000, 23.4000]],
#        dtype=torch.float64)
# label:
# tensor([[10.8000,  8.2000],
#         [27.0000, 21.4000]], dtype=torch.float64)
# input:
# tensor([[  4.4000,   2.1000,   5.0000,   0.7000,   2.0000, -10.2000,   0.7000,
#          -10.3000,   1.5000,  -2.3000,   4.4000,   1.5000,   7.6000,   1.8000],
#         [ -8.9000, -14.6000,   0.5000,  -9.0000,   0.2000, -15.4000, -10.4000,
#          -19.5000,  -3.5000, -11.6000,  -2.1000, -10.8000,  -3.7000,  -8.4000]],
#        dtype=torch.float64)
# label:
# tensor([[  1.8000, -10.6000],
#         [  0.0000,  -3.8500]], dtype=torch.float64)
# input:
# tensor([[13.8000,  2.5000, 13.0000,  2.7000,  6.7000, -0.2000,  2.1000, -0.9000,
#           7.8000,  1.5000,  7.2000,  2.4000,  4.3000,  1.5000],
#         [ 5.9000, -2.1000, -1.5000, -5.8000,  0.8000, -6.7000,  2.5000, -3.6000,
#           3.1000, -2.5000,  0.2000, -9.7000,  6.6000, -4.6000]],
#        dtype=torch.float64)
# label:
# tensor([[10.7000,  2.2000],
#         [13.4000,  3.6000]], dtype=torch.float64)
# input:
# tensor([[12.0000,  4.1000, 15.1000,  5.6000, 21.2000,  8.3000, 19.4000, 12.7000,
#          20.0000, 11.6000, 21.7000, 10.9000, 17.5000, 10.7000],
#         [11.4000,  0.4000, 10.9000,  2.1000,  2.1000, -0.8000,  4.0000, -0.2000,
#           3.0000, -0.4000,  3.8000, -0.2000,  9.0000,  0.3000]],
#        dtype=torch.float64)
# label:
# tensor([[23.5000, 11.1000],
#         [ 3.4000, -5.5000]], dtype=torch.float64)
# input:
# tensor([[ -1.1000, -12.8000,   7.1000,  -3.9000,   9.0000,   5.6000,  15.2000,
#            4.6000,   4.6000,   1.3000,   3.7500,   1.3000,   2.9000,  -3.3000],
#         [  1.8000,  -3.5000,   0.4000,  -3.3000,  11.4000,   0.4000,  10.9000,
#            2.1000,   2.1000,  -0.8000,   4.0000,  -0.2000,   3.0000,  -0.4000]],
#        dtype=torch.float64)
# label:
# tensor([[-1.8000, -5.5000],
#         [ 3.8000, -0.2000]], dtype=torch.float64)
# input:
# tensor([[11.3000,  9.6000, 15.4000, 10.1000, 15.7000,  8.2000, 10.5000,  6.3000,
#          11.0000,  5.9000,  9.9000,  2.9000,  6.6000,  1.8000],
#         [27.7000, 17.8000, 28.1000, 17.0000, 27.3000, 15.8000, 25.9000, 16.6000,
#          23.8000, 15.2000, 23.6000, 13.9000, 24.1000, 16.8000]],
#        dtype=torch.float64)
# label:
# tensor([[ 8.6000,  1.3000],
#         [23.1000, 17.1000]], dtype=torch.float64)
# input:
# tensor([[ 3.4000,  0.2000,  5.8000,  3.3000,  5.3000,  1.3000,  3.8000,  0.9000,
#           3.5000, -1.8000,  3.4000, -3.7000,  5.7000, -0.9000],
#         [26.4000, 19.6000, 29.7000, 18.5000, 28.6000, 18.5000, 30.5000, 19.8000,
#          29.3000, 17.4000, 29.8000, 20.5000, 23.8000, 15.7000]],
#        dtype=torch.float64)
# label:
# tensor([[ 9.1000,  3.4000],
#         [23.8000, 14.4000]], dtype=torch.float64)
# input:
# tensor([[ -6.3000, -10.8000,  -7.3000, -10.8000,  -1.9000, -12.8000,  -3.5000,
#           -8.4000,   0.6000,  -5.5000,   1.1000,  -2.1000,   1.5000,  -8.8000],
#         [ 27.3000,  16.3000,  26.1000,  15.2000,  26.1000,  16.2000,  22.3000,
#           16.2000,  25.9000,  15.0000,  20.6000,  11.0000,  14.8000,   8.2000]],
#        dtype=torch.float64)
# label:
# tensor([[ -8.5000, -14.5000],
#         [ 20.8000,   8.0000]], dtype=torch.float64)
# input:
# tensor([[28.4000, 18.2000, 26.6000, 19.6000, 27.0000, 17.9000, 26.8000, 17.3000,
#          26.4000, 19.7000, 28.7000, 18.5000, 25.4000, 17.9000],
#         [24.8000, 19.8000, 28.1000, 19.9000, 30.1000, 19.7000, 31.6000, 20.9000,
#          26.4000, 20.8000, 29.1000, 21.4000, 25.9000, 18.9000]],
#        dtype=torch.float64)
# label:
# tensor([[23.3000, 15.4000],
#         [23.0000, 15.3000]], dtype=torch.float64)
# input:
# tensor([[11.5000,  3.2000, 12.2000,  3.0000, 14.1000,  3.5000, 15.2000,  6.5000,
#          18.3000, 10.7000, 25.3000, 10.0000, 12.1000,  1.9000],
#         [10.9000,  1.9000,  6.2000,  0.4000, 15.0000,  5.4000, 18.0000,  9.3000,
#          17.9000,  8.9000, 17.6000,  9.0000, 15.3000, 11.1000]],
#        dtype=torch.float64)
# label:
# tensor([[ 8.9000,  0.6000],
#         [12.4000,  4.7000]], dtype=torch.float64)
# input:
# tensor([[29.4000, 21.0000, 29.1000, 21.2000, 24.5000, 20.8000, 24.5000, 20.4000,
#          24.8000, 16.7000, 21.8000, 15.3000, 26.5000, 13.3000],
#         [17.9000,  4.1000,  8.7000,  4.8000, 12.3000,  6.0000,  8.5000,  4.9000,
#           5.4000, -0.5000,  6.7000,  0.6000,  7.1000,  3.0000]],
#        dtype=torch.float64)
# label:
# tensor([[18.0000, 10.7000],
#         [ 9.4000,  1.3000]], dtype=torch.float64)
# input:
# tensor([[15.0000,  5.4000, 18.0000,  9.3000, 17.9000,  8.9000, 17.6000,  9.0000,
#          15.3000, 11.1000, 12.4000,  4.7000,  8.1000,  2.9000],
#         [21.7000, 16.9000, 22.0000, 16.8000, 23.1000, 17.9000, 24.8000, 17.9000,
#          22.5000, 18.6000, 23.1000, 17.2000, 26.9000, 17.2000]],
#        dtype=torch.float64)
# label:
# tensor([[ 4.9000,  1.7000],
#         [26.2000, 19.5000]], dtype=torch.float64)
# input:
# tensor([[19.3000,  8.9000, 16.3000,  6.1000, 12.2000,  4.5000, 15.9000,  6.6000,
#          17.6000,  9.3000, 13.1000,  8.6000, 11.4000,  8.5000],
#         [ 3.8000,  1.2000,  6.5000,  1.4000, 12.0000,  5.2000, 11.3000,  0.3000,
#           2.1000, -0.3000,  3.3000, -1.2000, -0.5000, -5.4000]],
#        dtype=torch.float64)
# label:
# tensor([[16.5000,  8.3000],
#         [ 0.7000, -5.9000]], dtype=torch.float64)
# input:
# tensor([[22.5000, 11.3000, 16.2000,  8.3000, 19.6000,  5.8000, 17.3500,  6.1333,
#          15.1000,  6.4667, 21.3000,  6.8000, 25.6000, 11.3000],
#         [22.7000, 15.4000, 19.3000,  7.4000, 17.3000,  8.1000, 20.3000, 11.4000,
#          30.1000, 13.6000, 21.9000, 12.1000, 24.1000, 13.1000]],
#        dtype=torch.float64)
# label:
# tensor([[26.3000, 13.7000],
#         [27.2000, 16.4000]], dtype=torch.float64)
# input:
# tensor([[ 2.4000, -4.5000,  3.7000, -2.4000,  5.9000, -0.1000,  8.1000,  3.4000,
#           7.8000, -5.5000, -5.3000, -8.8000, -0.8000, -8.2000],
#         [27.1000, 19.4000, 23.2000, 15.5000, 24.0000, 12.7000, 23.8000, 14.9000,
#          21.8000, 12.8000, 21.9000, 13.5000, 24.1000, 12.3000]],
#        dtype=torch.float64)
# label:
# tensor([[-6.1000, -8.9000],
#         [25.1000, 13.7000]], dtype=torch.float64)
# input:
# tensor([[ -0.1000,  -5.1000,  -1.2000, -10.6000,  -1.6000, -10.1000,   5.0000,
#           -2.4000,   4.2000,  -6.7000,  -0.9000,  -6.3000,  -0.6000, -10.1000],
#         [ -0.4000,  -4.5000,  -1.6000,  -7.5000,  -2.6000,  -6.3000,  -2.2000,
#           -4.7000,  -2.2000,  -5.7000,  -3.9000,  -7.0000,  -4.4000, -10.0000]],
#        dtype=torch.float64)
# label:
# tensor([[  2.5000, -10.4000],
#         [ -0.9000, -10.7000]], dtype=torch.float64)
# input:
# tensor([[10.5000,  6.0000,  9.4000,  5.1000,  5.0000, -0.7000,  7.3000,  0.0000,
#           7.9000,  2.7000,  9.6000,  5.5000, 16.0000,  6.2000],
#         [25.1000, 16.8000, 24.9000, 17.1000, 27.7000, 16.5000, 21.1000, 16.3000,
#          23.8000, 15.2000, 25.5000, 19.3000, 21.8000, 17.8000]],
#        dtype=torch.float64)
# label:
# tensor([[ 9.4000,  1.2000],
#         [26.1000, 18.1000]], dtype=torch.float64)
# input:
# tensor([[ -3.7000,  -9.9000,  -7.0000, -14.3000,   2.0000, -14.0000,   5.9000,
#           -1.3000,   4.2000,  -3.1000,   4.8000,  -6.1000,  -6.1000, -11.3000],
#         [ 27.6000,  16.3000,  25.3000,  15.2000,  22.6000,  12.9000,  24.8000,
#           14.3000,  23.6000,  14.4000,  25.2000,  12.6000,  27.0000,  15.2000]],
#        dtype=torch.float64)
# label:
# tensor([[ -2.3000, -11.7000],
#         [ 28.8000,  17.0000]], dtype=torch.float64)
# input:
# tensor([[16.1000,  6.9000, 16.9000,  9.7000, 20.3000,  9.9000, 12.2000,  5.0000,
#          11.8000,  4.9000, 18.3000,  5.7000, 10.5000,  4.7000],
#         [26.1000, 16.8000, 26.7000, 17.1000, 24.7250, 20.0000, 22.7500, 17.7333,
#          20.7750, 15.4667, 18.8000, 13.2000, 23.4000, 13.2000]],
#        dtype=torch.float64)
# label:
# tensor([[17.1000,  6.9000],
#         [20.4000, 13.6000]], dtype=torch.float64)
# input:
# tensor([[  8.9000,   2.3000,  11.3000,   6.2000,   7.2000,   5.4000,   7.2000,
#            4.5000,   7.0000,   3.6000,  12.1000,   4.0000,  14.9000,   5.8000],
#         [  9.1000,   0.1000,   0.1000, -11.2000,  -2.4000, -12.9000,   4.5000,
#           -6.8000,  15.9000,   3.8000,  12.9000,   0.0000,   4.5000,  -5.5000]],
#        dtype=torch.float64)
# label:
# tensor([[16.7000,  5.5000],
#         [ 2.9000, -8.2000]], dtype=torch.float64)
# input:
# tensor([[22.5000, 20.0000, 28.6000, 18.3000, 29.3000, 18.5000, 30.3000, 19.2000,
#          28.3000, 17.7000, 26.3000, 15.9000, 28.8000, 19.8000],
#         [24.4000, 12.6000, 24.8000, 14.6000, 24.2000, 15.2000, 19.3000, 16.0000,
#          16.6000, 14.9000, 18.4000, 15.2000, 22.2000, 15.0000]],
#        dtype=torch.float64)
# label:
# tensor([[31.2000, 17.2000],
#         [15.2000,  5.9000]], dtype=torch.float64)
# input:
# tensor([[23.3000, 15.4000, 24.3000, 13.4000, 23.9000, 14.7000, 23.2000, 15.9000,
#          19.3000, 14.3000, 18.1000, 13.3000, 23.5000, 13.7000],
#         [ 4.0000, -0.1000,  7.4000, -1.1000, 13.7000,  3.7000, 13.2000,  9.1000,
#          10.5000,  6.0000,  9.4000,  5.1000,  5.0000, -0.7000]],
#        dtype=torch.float64)
# label:
# tensor([[17.0000, 14.9000],
#         [ 7.3000,  0.0000]], dtype=torch.float64)

# %% [markdown]
# # RNN TRAINING

# %%
import os 
from torch.utils.data.sampler import SubsetRandomSampler 
from torchvision import datasets, models, transforms 
import torch.optim as optim
import numpy as np 
import matplotlib.pyplot as plt
import time 
import torch
import torch.nn as nn
import torch.nn.functional as F 
import torch.optim 
import torchvision
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision.transforms as transforms 
use_cuda = True

#we prolly need cuda? to speed things up?

# %% [markdown]
# ### Helper functions

# %%
def get_model_name(name, batch_size, learning_rate, epoch):
    """ Generate a name for the model consisting of all the hyperparameter values

    Args:
        config: Configuration object containing the hyperparameters
    Returns:
        path: A string with the hyperparameter name and value concatenated
    """
    path = "/content/gdrive/My Drive/APS360 Team/milestone 1/Checkpoints/weatherANNmodel_{0}_bs{1}_lr{2}_epoch{3}".format(name,
                                                   batch_size,
                                                   learning_rate,
                                                   epoch)
    return path

# %%
# not sure if this is needed

def normalize_label(labels):
    """
    Given a tensor containing 2 possible values, normalize this to 0/1

    Args:
        labels: a 1D tensor containing two possible scalar values
    Returns:
        A tensor normalize to 0/1 value
    """
    max_val = torch.max(labels)
    min_val = torch.min(labels)
    norm_labels = (labels - min_val)/(max_val - min_val)
    return norm_labels

# %%
def plot_training_curve(path):
    """ Plots the training curve for a model run, given the csv files
    containing the train/validation error/loss.

    Args:
        path: The base path of the csv files produced during training
    """
    import matplotlib.pyplot as plt
    train_err = np.loadtxt("{}_train_err.csv".format(path))
    val_err = np.loadtxt("{}_val_err.csv".format(path))
    train_loss = np.loadtxt("{}_train_loss.csv".format(path))
    val_loss = np.loadtxt("{}_val_loss.csv".format(path))
    plt.title("Train vs Validation Error")
    n = len(train_err) # number of epochs
    plt.plot(range(1,n+1), train_err, label="Train")
    plt.plot(range(1,n+1), val_err, label="Validation")
    plt.xlabel("Epoch")
    plt.ylabel("Error")
    plt.legend(loc='best')
    plt.show()
    plt.title("Train vs Validation Loss")
    plt.plot(range(1,n+1), train_loss, label="Train")
    plt.plot(range(1,n+1), val_loss, label="Validation")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.show()

# %% [markdown]
# ### Visualization of data

# %%
# laterrrrrrr

# %% [markdown]
# ### Architecture

# %%
import logging
import datetime

import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import Variable
import matplotlib.pyplot as plt
import matplotlib

# idk what line 12 does but i guess I am keeping it
log = logging.getLogger(__name__)

# %%
# Figure out RNN architecture
# potentially helpful links:
# https://chandlerzuo.github.io/blog/2017/11/darnn
# https://gist.github.com/lizadaly/2b19fd6f758ffd2e8ab9ec7d1f3f4b2c             <- USING THIS AS A TEMPLATE FOR TIME BASED RNN
#

# %%
# hmmmm -> should seqlen be the number of inputs we put in? tbh a lil confused
# input size will always be 14, output size will always be 2 
# not sure what n_layers does but thats fine
# dont think we utilize dropout either
class weatherRNN(nn.Module):

    def __init__(self, hidden_size, input_size = 14, output_size = 2, n_layers = 1): #,dropout=DROPOUT
        super(weatherRNN, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, n_layers, batch_first=True) # there is RNN, GRU, LSTM
        self.decoder = nn.Linear(hidden_size, output_size)

    def forward(self, inp,  hidden = None):
        out = self.rnn(inp, hidden)
        out = self.decoder(out)
        return out

# %%
# # hmmmm -> should seqlen be the number of inputs we put in? tbh a lil confused
# # input size will always be 14, output size will always be 2 
# # not sure what n_layers does but thats fine
# # dont think we utilize dropout either
# class weatherRNN(nn.Module):

#     def __init__(self, input_size = 14, hidden_size = 30, output_size = 2, n_layers = 1): #,dropout=DROPOUT
#         super(weatherRNN, self).__init__()
#         self.input_size = input_size
#         self.hidden_size = hidden_size
#         self.output_size = output_size
#         self.n_layers = n_layers

#         #self.encoder = nn.Embedding(input_size, hidden_size) # has nothing to do with "word embeddings" -> just indicate non linearity
#         # this is a drop out layer to prevent overfitting - we can get rid of it if we wanted to
#         #self.m = nn.Sequential(nn.ReLU(), nn.Dropout(p=0.2), nn.ReLU())
#         # encoder - converting back
#         self.rnn = nn.RNN(input_size, hidden_size, n_layers, batch_first=True) # there is RNN, GRU, LSTM
#         self.decoder = nn.Linear(hidden_size, output_size)

#     def forward(self, inp,  hidden=None):
#         # Look up the embedding
#         # inp = self.emb(inp)
#         # inp = self.encoder(inp)

#         # Set an initial hidden state and cell state
#         # h0 = num_layers * num_directions, batch, hidden_size
#         # NOT BI DIRECTIONAL: so num_directions = 1
#         # batch == size of the input
#         # hidden_size == predefined hidden size
#         print(inp.size())
#         print(self.n_layers)
#         print(len(inp))
#         print(self.hidden_size)
        
#         #h0 = torch.zeros((self.n_layers)*1, inp.size(0), self.hidden_size)
#         # h0 = torch.zeros((self.n_layers)*1, len(inp), self.hidden_size)
        
#         # print(h0.size())

#         # Forward propagate the rnn
#         out, _ = self.rnn(inp, hidden)
#         # Pass the output of the last time step to the classifier
#         output = self.decoder(output)
#         return out
#         # don't need the hidden state yet

# %% [markdown]
# ### Training

# %%
# Error defined as prediction being off more than 5°C
def compute_error_rnn(outputs, labels):
  err = 0.0
  number_items = 0
  for j, out in enumerate(outputs, 0):
      err += (abs(labels[j][0] - out[0]) > 5)
      err += (abs(labels[j][1] - out[1]) > 5)
      number_items += 2

  return err, number_items

# %%
def get_accuracy_rnn(model, data_loader):
    correct, total = 0, 0
    for i, labels in data_loader:
        inputs, labels = data
        
        #To Enable GPU Usage
        if use_cuda and torch.cuda.is_available():
          inputs = inputs.cuda()
          labels = labels.cuda()
        
        outputs = net(inputs.float())
        loss = criterion(outputs, labels.float()) 
        total_loss += loss.item()
      
        cur_err, cur_num = compute_error_rnn(outputs, labels)
        total_err += cur_err
        number_items += cur_num
    err = float(total_err) / number_items
    loss = float(total_loss) / (i + 1)
    return err, loss

# idk what these do exactly tho hmmm
# test_loader = TweetBatcher(test, batch_size=64, drop_last=False)
# get_accuracy(model, test_loader)

# %%
def train_rnn_network(model, trainingSet, validationSet, num_epochs, batch_size, learning_rate):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

    train_loader = torch.utils.data.DataLoader(trainingSet, batch_size=batch_size, 
                                            num_workers=1, shuffle=True)
    val_loader = torch.utils.data.DataLoader(validationSet, batch_size=batch_size, 
                                            num_workers=1, shuffle=True)


    losses, train_acc, valid_acc = [], [], []
    #hidden = tf.zeros() # have to some
    epochs = []
    for epoch in range(num_epochs):
        for i, labels in enumerate(train_loader, 0): # input is our 7 days, labels is our expected output
            inp, label = data
            print(inp.size())
            optimizer.zero_grad()
            output = model(inp)
            loss = criterion(pred, label)
            loss.backward()
            optimizer.step()
        losses.append(float(loss))

        epochs.append(epoch)
        train_acc.append(get_accuracy_rnn(model, train_loader))
        valid_acc.append(get_accuracy_rnn(model, valid_loader))
        print("Epoch %d; Loss %f; Train Acc %f; Val Acc %f" % (
              epoch+1, loss, train_acc[-1], valid_acc[-1]))
    # plotting
    plt.title("Training Curve")
    plt.plot(losses, label="Train")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Training Curve")
    plt.plot(epochs, train_acc, label="Train")
    plt.plot(epochs, valid_acc, label="Validation")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(loc='best')
    plt.show()

# %%
weather_rnn = weatherRNN(hidden_size=100)
train_rnn_network(weather_rnn.cuda(), trainingSet=trainingSet, validationSet=validationSet, batch_size=30, learning_rate=0.01, num_epochs=30)
# Out:
# torch.Size([2, 14])
# torch.Size([2, 14, 1])
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-a3dfc8ddf903> in <module>()
#       1 weather_rnn = weatherRNN(hidden_size=100)
# ----> 2 train_rnn_network(weather_rnn.cuda(), trainingSet=trainingSet, validationSet=validationSet, batch_size=30, learning_rate=0.01, num_epochs=30)
#
# <ipython-input-22-938abf4d9472> in train_rnn_network(model, trainingSet, validationSet, num_epochs, batch_size, learning_rate)
#      23
#      24             optimizer.zero_grad()
# ---> 25             output = model(inp2)
#      26             loss = criterion(pred, label)
#      27             loss.backward()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-18-a67176bc670b> in forward(self, inp, hidden)
#       7
#       8     def forward(self, inp,  hidden = None):
# ----> 9         out = self.rnn(inp, hidden)
#      10         out = self.decoder(out)
#      11         return out
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     211             hx = self.permute_hidden(hx, sorted_indices)
#     212
# --> 213         self.check_forward_args(input, hx, batch_sizes)
#     214         _impl = _rnn_impls[self.mode]
#     215         if batch_sizes is None:
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in check_forward_args(self, input, hidden, batch_sizes)
#     178     def check_forward_args(self, input, hidden, batch_sizes):
#     179         # type: (Tensor, Tensor, Optional[Tensor]) -> None
# --> 180         self.check_input(input, batch_sizes)
#     181         expected_hidden_size = self.get_expected_hidden_size(input, batch_sizes)
#     182
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/rnn.py in check_input(self, input, batch_sizes)
#     157             raise RuntimeError(
#     158                 'input.size(-1) must be equal to input_size. Expected {}, got {}'.format(
# --> 159                     self.input_size, input.size(-1)))
#     160
#     161     def get_expected_hidden_size(self, input, batch_sizes):
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 14, got 1

# %%
model_path = get_model_name("weatherRNN", batch_size=30, learning_rate=0.01, epoch=30)

plot_training_curve(model_path)

# %% [markdown]
# ### Tuning

# %% [markdown]
# best model???
